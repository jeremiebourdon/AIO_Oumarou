# %% [markdown]
# # AIO Computation function definitions

# %%
# Libraries
import cobra
import numpy as np
import pyEQL.chemical_formula

# function definitions

def GetComposition_old(formula,atom="C"):
    ch=""
    flag=False
    for c in formula:
        if c == atom:
            flag=True
        else:
            if c.isnumeric() and flag:
                ch=ch+c
            else:
                flag=False
    if ch == "":
        return 0
    else:
        return int(ch)


def GetComposition(formula,atom="C"):
#    print("formula : ",formula)
    if (formula == None or formula == ""):
        formula = "S"
    try:
        return pyEQL.chemical_formula.get_element_mole_ratio(formula,atom)
    except ValueError:
        return 0
    
def getSign(r,fva=0):
    if fva == 0:
        minim=r.lower_bound
        maxim=r.upper_bound
    else:
        minim=fva["minimum"].get(r.id)
        maxim=fva["maximum"].get(r.id)
    if (abs(minim)+abs(maxim)>0.01):
        if (minim*maxim<0):
            return 0
        else:
            if (maxim<=0):
                return -1
            else:
                return 1
    else:
        return 0
            

ReactInputTable=dict()
ReactProductTable=dict()

def ReactionInputs(r,sign=1):
    if not ReactInputTable.get(r.id):
        ReactInputTable[r.id] = ReactionInputsLong(r,sign)
    return ReactInputTable.get(r.id)
 
        
def ReactionProducts(r,sign=1):
    if not ReactProductTable.get(r.id):
        ReactProductTable[r.id] = ReactionProductsLong(r,sign)
    return ReactProductTable.get(r.id)
    
def ReactionInputsLong(r,sign=1):
    res=list()
    for m in r.metabolites:
        if (sign*r.get_coefficient(m)<-0.01):
            res.append(m)
    return res
        
def ReactionProductsLong(r,sign=1):
    res=list()
    for m in r.metabolites:
        if (sign*r.get_coefficient(m)>0.01):
            res.append(m)
    return res
    

def In(r,m,atom="C"):
    res=0
    if m in ReactionProducts(r,getSign(r)):
        res=abs(r.get_coefficient(m))*GetComposition(m.formula,atom)
        somme=0
        for met in ReactionInputs(r,getSign(r)):
            somme+=abs(r.get_coefficient(met))*GetComposition(met.formula,atom)
        if not somme == 0:
            res=res/somme
        else:
            res=1
    return res


def RescaleModel(model,frac=0.5):
    fva=cobra.flux_analysis.flux_variability_analysis(model,fraction_of_optimum=frac).to_dict()
    for r in model.reactions:
        r.lower_bound = fva["minimum"].get(r.id)
        r.upper_bound = fva["maximum"].get(r.id)
        
        
    
def value_of_D(mk,mi,V,atom="C"):
    # case 1 : r is the exchange reactions for m input
    if mk == mi:
        return 1
    # General case
    res=0
    for r in isConsumedBy[mi.id]:
            mr=metRate(mi,V)
            if not mr==0: 
                res -= abs(r.get_coefficient(mi)) * V.get(r.id) *In(r,mk,atom) / mr
    return res 



def getMetabolitLists(model):
    LMet=list()
    for m in model.metabolites:
        LMet.append(m)
    LMetInputs=list()
    for m in LMet:
        flag=False
        for r in m.reactions:
            if len(ReactionInputs(r,getSign(r)))==0 and m in ReactionProducts(r,getSign(r)):
                flag=True
        if flag:
#            print(m.id,"is an input")
            LMetInputs.append(m)       
    LMetOutputs=list()
    for m in LMet:
        flag=False
        for r in m.reactions:
            if len(ReactionProducts(r,getSign(r)))==0 and m in ReactionInputs(r,getSign(r)):
                flag=True
        if flag:
#            print(m.id,"is an output")
            LMetOutputs.append(m)

    LMetOthers=list()
    for m in LMet:
        # Beurkkkk !!!!
        flag=True
        for r in m.reactions:
            if len(ReactionProducts(r,getSign(r)))==0 and m in ReactionInputs(r,getSign(r)):
                flag=False
            if len(ReactionInputs(r,getSign(r)))==0 and m in ReactionProducts(r,getSign(r)):
                flag=False
        if flag:
#            print(m.id,"is an neither an input, nor an output")
            LMetOthers.append(m)
    LMet = LMetInputs+LMetOthers+LMetOutputs
    return LMet,LMetInputs,LMetOthers,LMetOutputs

def getMatD(model,V,atom):
    # get the list of metabolites
    LMet, LIn, LOthers, LOut = getMetabolitLists(model)
    MatD=np.zeros((len(LMet),len(LMet)))
    i=0
    for mi in LMet:
        k=0
        for mk in LMet:
            MatD[k,i]=value_of_D(mk,mi,V,"C")
            k+=1
        i+=1
    return matD

def PrintRepartition(model,V,atom="C",aff=True,precision=1e-10):
    ReactInputTable.clear()
    ReactProductTable.clear()
    EnrichModel(model)
    # get the list of metabolites
    res=dict()
    print("... Creating the metabolite lists")
    LMet, LIn, LOthers, LOut = getMetabolitLists(model)
    print("... Creating matrix D")
    MatD=np.zeros((len(LMet),len(LMet)))
    i=0
    for mi in LMet:
        k=0
        for mk in LMet:
            MatD[k,i]=value_of_D(mk,mi,V,atom)
            k+=1
        i+=1
    print("... Inverting matrix D")
    invmatD=np.linalg.inv(MatD)
    for i in range(len(LMet)):
        ch = "X_"+LMet[i].id+"*("+str(GetComposition(LMet[i].formula,atom))+")"+" = "
        res[LMet[i].id]=dict()
        for k in range(len(LIn)):
            if (invmatD[i,k] > precision and (GetComposition(LMet[k].formula,atom))>0.01):
                ch += " + "+str(invmatD[i,k])+" * X_"+LMet[k].id+"("+str(GetComposition(LMet[k].formula,atom))+")"
                res[LMet[i].id][LMet[k].id]=invmatD[i,k]
        if aff:
            print(ch)
    return res

isProducedBy=dict()
isConsumedBy=dict()

def EnrichModel(model):
    isProducedBy.clear()
    isConsumedBy.clear()
    for m in model.metabolites:
        isProducedBy[m.id]=list()
        isConsumedBy[m.id]=list()
        for r in m.reactions:
            if m in ReactionProducts(r,getSign(r)):
                isProducedBy[m.id].append(r)
            if m in ReactionInputs(r,getSign(r)):
                isConsumedBy[m.id].append(r)

def metRate(m,V):
    res=0
    for r in isProducedBy[m.id]:
        res+=r.get_coefficient(m)*V.get(r.id)
    return res

def metRate_inv(m,V):
    res=0
    for r in m.reactions:
        if m not in ReactionProducts(r,getSign(r)):
            res+=abs(r.get_coefficient(m))*V.get(r.id)
    return res

def FixModelFluxes(model,V):
    for r in model.reactions:
        value = V.get(r.id)
        r.lower_bound = value
        r.upper_bound = value

# %%
# pour compléter les modèles de BIGG au cas où il n'y aurait pas le champs "formula"

f=open("NA_Offline/chem_prop.tsv","r")

MNXDict=dict()

for l in f:
    t=l.split("\t")
    if (len(t)>2):
        MNXDict[t[0]]=t[2]
    
f.close()

f=open("NA_Offline/bigg_models_metabolites.txt","r")

MetDict=dict()

for l in f:
    t=l.split("\t")
    address=t[4]
    pos=address.find("http://identifiers.org/metanetx.chemical")
    address=address[pos:].replace("http://identifiers.org/metanetx.chemical/","")
    pos=address.find(";")
    if pos>0:
        address=address[:(pos)]
    MetDict[t[0]]=[address, MNXDict.get(address)]
    
f.close()





def Model_Missing_Formula(model):
    for m in model.metabolites:
        if m.formula == None:
            if (MetDict.get(m.id)[1] != None):
                m.formula = MetDict.get(m.id)[1]
            else:
                m.formula="C1"

# %% [markdown]
# # Test on a tiny example

# %% [markdown]
# ## Model definition

# %%
from cobra import Model, Reaction, Metabolite
model = Model('example_model')

# set of reactions
reactions = dict()
for i in range(1,8):
    reactions["R"+str(i)] = Reaction("R"+str(i))
    reactions["R"+str(i)].name = "R"+str(i)
    reactions["R"+str(i)].subsystem = 'Body'
    reactions["R"+str(i)].lower_bound = 0.  # This is the default
    reactions["R"+str(i)].upper_bound = 1000.  # This is the default
#    reactions["R"+str(i)].objective_coefficient = 0. # this is the default
    print ("Creating R"+str(i))
# set of metabolites
A = Metabolite('A', name='A', compartment='c', formula = 'C1')
B = Metabolite('B', name='B', compartment='c', formula = 'C3')
C = Metabolite('C', name='C', compartment='c', formula = 'C5')
D = Metabolite('D', name='D', compartment='c', formula = 'C4')
E = Metabolite('E', name='E', compartment='c', formula = 'C2')

reactions["R1"].add_metabolites({A:-2, B:-1, C: 1})
reactions["R2"].add_metabolites({B:-1, C:-1, D: 1, E: 2})
reactions["R3"].add_metabolites({A:-4, D: 1})
reactions["R4"].add_metabolites({A:1})
reactions["R5"].add_metabolites({B:1})
reactions["R6"].add_metabolites({D: -1})
reactions["R7"].add_metabolites({E: -1})


reactions["R4"].lower_bound = 1
reactions["R4"].upper_bound = 6
#reactions["R4"].objective_coefficient = 1
reactions["R7"].lower_bound = 1
reactions["R7"].upper_bound = 4
#reactions["R7"].objective_coefficient = 1

for i in range(1,8):
    model.add_reaction(reactions["R"+str(i)])
    model.reactions.get_by_id("R"+str(i)).objective_coefficient = 0

model.objective = model.reactions.R4.flux_expression + model.reactions.R7.flux_expression
# Out:
# Creating R1
# Creating R2
# Creating R3
# Creating R4
# Creating R5
# Creating R6
# Creating R7

# %%
# Need to have the "real" lb and ub. Performing a FVA (with a f_to_opt=0.5) allows to get them
RescaleModel(model,0.5)

# Compute one vector
fba = model.optimize()
V=fba.x_dict
#FixModelFluxes(model,V)

PrintRepartition(model,V)
# Out:
# ... Creating the metabolite lists
# ... Creating matrix D
# ... Inverting matrix D
# X_A*(1) =  + 1.0 * X_A(1)
# X_B*(3) =  + 1.0 * X_B(3)
# X_C*(5) =  + 0.666666666667 * X_A(1) + 0.5 * X_B(3)
# X_D*(4) =  + 0.666666666667 * X_A(1) + 0.5 * X_B(3)
# X_E*(2) =  + 0.333333333333 * X_A(1) + 0.5 * X_B(3)
# {'A': {'A': 1.0},
#  'B': {'B': 1.0},
#  'C': {'A': 0.66666666666666663, 'B': 0.5},
#  'D': {'A': 0.66666666666666663, 'B': 0.5},
#  'E': {'A': 0.33333333333333331, 'B': 0.5}}

# %% [markdown]
# # Test of a middle size example (e_coli_core from BIGG)

# %%
import time

globalstart = time.time()

start = time.time()
print("Reading the model")
model=cobra.io.read_sbml_model('NA_Offline/e_coli_core.xml')
end = time.time()
print("       finishing in",end - start," s")

start = time.time()
print("Scaling the model")
RescaleModel(model,0.5)
Model_Missing_Formula(model)

end = time.time()
print("       finishing in",end - start," s")

start = time.time()
print("Performing a FBA")
fba = model.optimize()
end = time.time()
print("       finishing in",end - start," s")
V=fba.x_dict

start = time.time()
print("Pick a sample flux vector")
VD=cobra.flux_analysis.sample(model,1).to_dict()
V=dict()
for r in VD:
    V[r]=VD[r].get(0)
end = time.time()
print("       finishing in",end - start," s")

    
start = time.time()
print("AIO Computation")
res=PrintRepartition(model,V)
end = time.time()
print("       finishing in",end - start," s")

globalend = time.time()
print("Global execution time = ",globalend - globalstart," s")
# Out:
# Reading the model
#        finishing in 0.1217658519744873  s
# Scaling the model
#        finishing in 0.04843282699584961  s
# Performing a FBA
#        finishing in 0.0017139911651611328  s
# Pick a sample flux vector
#        finishing in 0.15105414390563965  s
# AIO Computation
# ... Creating the metabolite lists
# ... Creating matrix D
# ... Inverting matrix D
# X_glc__D_e*(6) =  + 1.0 * X_glc__D_e(6)
# X_nh4_e*(0) =
# X_o2_e*(0) =
# X_pi_e*(0) =
# X_13dpg_c*(3) =  + 0.0672528412635 * X_glc__D_e(6)
# X_2pg_c*(3) =  + 0.0456346669238 * X_glc__D_e(6)
# X_3pg_c*(3) =
# X_6pgc_c*(6) =  + 0.234650260561 * X_glc__D_e(6)
# X_6pgl_c*(6) =  + 0.234650260561 * X_glc__D_e(6)
# X_ac_c*(2) =
# X_acald_c*(2) =
# X_accoa_c*(23) =  + 0.385157658251 * X_glc__D_e(6)
# X_acon_C_c*(6) =  + 0.0508105497356 * X_glc__D_e(6)
# X_actp_c*(2) =  + 0.000431662205185 * X_glc__D_e(6)
# X_adp_c*(10) =  + 0.642081246606 * X_glc__D_e(6)
# X_akg_c*(5) =  + 0.0465038030739 * X_glc__D_e(6)
# X_amp_c*(10) =  + 0.103310964963 * X_glc__D_e(6)
# X_atp_c*(10) =  + 0.303277565423 * X_glc__D_e(6)
# X_cit_c*(6) =  + 0.0508105497356 * X_glc__D_e(6)
# X_co2_c*(1) =  + 0.0509148071129 * X_glc__D_e(6)
# X_co2_e*(1) =
# X_coa_c*(21) =  + 0.197680200789 * X_glc__D_e(6)
# X_dhap_c*(3) =
# X_e4p_c*(4) =
# X_etoh_c*(2) =
# X_f6p_c*(6) =  + 0.00568745386539 * X_glc__D_e(6)
# X_fdp_c*(6) =  + 0.0219115170003 * X_glc__D_e(6)
# X_for_c*(1) =  + 0.00230020238662 * X_glc__D_e(6)
# X_fru_e*(6) =
# X_fum_c*(4) =  + 4.30384313428 * X_glc__D_e(6)
# X_fum_e*(4) =
# X_g3p_c*(3) =
# X_g6p_c*(6) =  + 0.691174289173 * X_glc__D_e(6)
# X_gln__L_c*(5) =  + 0.0176122812759 * X_glc__D_e(6)
# X_gln__L_e*(5) =
# X_glu__L_c*(5) =  + 0.0636094923021 * X_glc__D_e(6)
# X_glx_c*(2) =  + 0.00610757944871 * X_glc__D_e(6)
# X_h2o_c*(0) =
# X_h_c*(0) =
# X_icit_c*(6) =  + 0.0508105497356 * X_glc__D_e(6)
# X_lac__D_c*(3) =
# X_mal__L_c*(4) =  + 0.0123619256658 * X_glc__D_e(6)
# X_mal__L_e*(4) =
# X_nad_c*(21) =  + 2.0419856578 * X_glc__D_e(6)
# X_nadh_c*(21) =  + 2.04904646646 * X_glc__D_e(6)
# X_nadp_c*(21) =  + 1.40966720006 * X_glc__D_e(6)
# X_nadph_c*(21) =  + 1.89748455445 * X_glc__D_e(6)
# X_nh4_c*(0) =
# X_o2_c*(0) =
# X_oaa_c*(4) =  + 0.0184442599577 * X_glc__D_e(6)
# X_pep_c*(3) =  + 0.0781922602321 * X_glc__D_e(6)
# X_pi_c*(0) =
# X_pyr_c*(3) =  + 0.37749650551 * X_glc__D_e(6)
# X_q8_c*(49) =  + 56.6595082985 * X_glc__D_e(6)
# X_q8h2_c*(49) =  + 56.6614206877 * X_glc__D_e(6)
# X_r5p_c*(5) =
# X_ru5p__D_c*(5) =  + 0.117296942048 * X_glc__D_e(6)
# X_s7p_c*(7) =
# X_succ_c*(4) =  + 4.29054873708 * X_glc__D_e(6)
# X_succoa_c*(25) =  + 0.0637212640133 * X_glc__D_e(6)
# X_xu5p__D_c*(5) =
# X_ac_e*(2) =  + 0.000285519545205 * X_glc__D_e(6)
# X_acald_e*(2) =  + 0.00430721359339 * X_glc__D_e(6)
# X_akg_e*(5) =
# X_etoh_e*(2) =  + 0.000212870496364 * X_glc__D_e(6)
# X_for_e*(1) =
# X_glu__L_e*(5) =
# X_h2o_e*(0) =
# X_h_e*(0) =
# X_lac__D_e*(3) =  + 0.00402319027842 * X_glc__D_e(6)
# X_pyr_e*(3) =
# X_succ_e*(4) =  + 0.0104196002812 * X_glc__D_e(6)
#        finishing in 0.24485993385314941  s
# Global execution time =  0.5692629814147949  s

# %% [markdown]
# # Test of a large size example (Pseudomonas Putida from BIGG)

# %%
import time

globalstart = time.time()

start = time.time()
print("Reading the model")
model=cobra.io.read_sbml_model('NA_Offline/iJN746.xml')
end = time.time()
print("       finishing in",end - start," s")

start = time.time()
print("Scaling the model")
RescaleModel(model,0.5)
Model_Missing_Formula(model)

end = time.time()
print("       finishing in",end - start," s")

start = time.time()
print("Performing a FBA")
fba = model.optimize()
end = time.time()
print("       finishing in",end - start," s")
V=fba.x_dict

start = time.time()
print("Pick a sample flux vector")
VD=cobra.flux_analysis.sample(model,1).to_dict()
V=dict()
for r in VD:
    V[r]=VD[r].get(0)
end = time.time()
print("       finishing in",end - start," s")

    
start = time.time()
print("AIO Computation")
PrintRepartition(model,V)
end = time.time()
print("       finishing in",end - start," s")

globalend = time.time()
print("Global execution time = ",globalend - globalstart," s")
# Out:
# Reading the model
#        finishing in 0.8422932624816895  s
# Scaling the model
#        finishing in 2.341830015182495  s
# Performing a FBA
#        finishing in 0.014899015426635742  s
# Pick a sample flux vector
#        finishing in 5.630018949508667  s
# AIO Computation
# ... Creating the metabolite lists
# ... Creating matrix D
# ... Inverting matrix D
# X_pqq_c*(14) =  + 1.0 * X_pqq_c(14)
# X_dna5mtc_c*(0) =
# X_mclPHAg_c*(0) =
# X_glc__D_e*(6) =  + 1.0 * X_glc__D_e(6)
# X_nh4_e*(0) =
# X_o2_e*(0) =
# X_pi_e*(0) =
# X_so4_e*(0) =
# X_co2_e*(1) =
# X_nadp_c*(21) =
# X_nadph_c*(21) =  + 1.23267035949 * X_pqq_c(14) + 0.118138403448 * X_glc__D_e(6)
# X_Lpipecol_c*(6) =  + 2.25908322209e-07 * X_pqq_c(14) + 2.16509209506e-08 * X_glc__D_e(6)
# X_1pipdn2c_c*(6) =
# X_h_c*(0) =
# X_atp_c*(10) =  + 0.27842864341 * X_pqq_c(14) + 0.118449595516 * X_glc__D_e(6)
# X_2dhglcn_c*(6) =
# X_6p2dhglcn_c*(6) =  + 3.67296008152e-06 * X_pqq_c(14) + 1.56255703679e-06 * X_glc__D_e(6)
# X_adp_c*(10) =  + 12.8744528758 * X_pqq_c(14) + 5.64258381046 * X_glc__D_e(6)
# X_2dhglcn_p*(6) =
# X_h_p*(0) =
# X_34dhcinm_p*(9) =
# X_34dhcinm_e*(9) =
# X_34dhcinm_c*(9) =
# X_34hpp_c*(9) =  + 4.33747726246e-06 * X_pqq_c(14) + 4.88467852351e-07 * X_glc__D_e(6)
# X_o2_c*(0) =
# X_co2_c*(1) =  + 3.0839101095 * X_pqq_c(14) + 0.235852577711 * X_glc__D_e(6)
# X_hgentis_c*(8) =  + 4.95453993946e-07 * X_pqq_c(14) + 5.57958771234e-08 * X_glc__D_e(6)
# X_R_3hdcoa_c*(31) =  + 11.2787267005 * X_pqq_c(14) + 1.6929648541 * X_glc__D_e(6)
# X_3hdecACP_c*(0) =
# X_ACP_c*(0) =
# X_coa_c*(21) =  + 39.7537857748 * X_pqq_c(14) + 5.96714185218 * X_glc__D_e(6)
# X_R_3hddcoa_c*(33) =  + 12.0034121553 * X_pqq_c(14) + 1.8017419384 * X_glc__D_e(6)
# X_3hddecACP_c*(0) =
# X_R_3hcddec5ecoa_c*(33) =  + 12.0004379354 * X_pqq_c(14) + 1.80129550062 * X_glc__D_e(6)
# X_3hcddec5eACP_c*(0) =
# X_3hmrsACP_c*(0) =
# X_R_3hmrscoa_c*(35) =  + 12.7245983402 * X_pqq_c(14) + 1.90999377362 * X_glc__D_e(6)
# X_R_3hcmrs7ecoa_c*(35) =  + 12.7214286669 * X_pqq_c(14) + 1.9095179978 * X_glc__D_e(6)
# X_3hcmrs7eACP_c*(0) =
# X_3hhexACP_c*(0) =
# X_R_3hhcoa_c*(27) =  + 9.81123934794 * X_pqq_c(14) + 1.47269136244 * X_glc__D_e(6)
# X_R_3hocoa_c*(29) =  + 10.5353840699 * X_pqq_c(14) + 1.58138728141 * X_glc__D_e(6)
# X_3hoctACP_c*(0) =
# X_tdec2eACP_c*(0) =
# X_h2o_c*(0) =
# X_tddec2eACP_c*(0) =
# X_t3c5ddeceACP_c*(0) =
# X_tmrs2eACP_c*(0) =
# X_t3c7mrseACP_c*(0) =
# X_3hpalmACP_c*(0) =
# X_tpalm2eACP_c*(0) =
# X_t3c9palmeACP_c*(0) =
# X_3hcpalm9eACP_c*(0) =
# X_3hoctaACP_c*(0) =
# X_toctd2eACP_c*(0) =
# X_3hcvac11eACP_c*(0) =
# X_t3c11vaceACP_c*(0) =
# X_3haACP_c*(0) =
# X_but2eACP_c*(0) =
# X_thex2eACP_c*(0) =
# X_toct2eACP_c*(0) =
# X_3hmp_c*(4) =  + 4.372924013e-07 * X_pqq_c(14) + 4.19945371921e-08 * X_glc__D_e(6)
# X_3hibutcoa_c*(25) =  + 2.73307750791e-06 * X_pqq_c(14) + 2.6246585743e-07 * X_glc__D_e(6)
# X_nad_c*(21) =  + 15.2950582241 * X_pqq_c(14) + 1.15385924881 * X_glc__D_e(6)
# X_nadh_c*(21) =  + 149.408182877 * X_pqq_c(14) + 4.88496200443 * X_glc__D_e(6)
# X_3mbzald_c*(8) =
# X_3mbzalc_c*(8) =
# X_m_tol_c*(8) =
# X_cchoxod_c*(7) =
# X_3mcat_c*(7) =
# X_succ_c*(4) =  + 1.86956047094 * X_pqq_c(14) + 0.232684407762 * X_glc__D_e(6)
# X_succoa_c*(25) =  + 55.6096782928 * X_pqq_c(14) + 4.45095524362 * X_glc__D_e(6)
# X_3oxoadp_c*(6) =  + 1.55094052614e-06 * X_pqq_c(14) + 5.95506532179e-07 * X_glc__D_e(6)
# X_oxadpcoa_c*(27) =  + 9.23737083434e-07 * X_pqq_c(14) + 9.05070011319e-08 * X_glc__D_e(6)
# X_3odecACP_c*(0) =
# X_3oddecACP_c*(0) =
# X_3ocddec5eACP_c*(0) =
# X_3omrsACP_c*(0) =
# X_3ocmrs7eACP_c*(0) =
# X_3opalmACP_c*(0) =
# X_3ocpalm9eACP_c*(0) =
# X_3ooctdACP_c*(0) =
# X_3ocvac11eACP_c*(0) =
# X_actACP_c*(0) =
# X_3ohexACP_c*(0) =
# X_3ooctACP_c*(0) =
# X_ocACP_c*(0) =
# X_malACP_c*(0) =
# X_dcaACP_c*(0) =
# X_cdec3eACP_c*(0) =
# X_ddcaACP_c*(0) =
# X_cddec5eACP_c*(0) =
# X_myrsACP_c*(0) =
# X_tdeACP_c*(0) =
# X_palmACP_c*(0) =
# X_hdeACP_c*(0) =
# X_butACP_c*(0) =
# X_hexACP_c*(0) =
# X_accoa_c*(23) =  + 85.9905294895 * X_pqq_c(14) + 9.47510657588 * X_glc__D_e(6)
# X_3oxoadp_p*(6) =
# X_34dhbz_c*(7) =  + 1.87031099983e-06 * X_pqq_c(14) + 7.18133544667e-07 * X_glc__D_e(6)
# X_34dhbz_p*(7) =
# X_T4hcinnm_c*(9) =
# X_coucoa_c*(30) =
# X_amp_c*(10) =  + 0.178887947776 * X_pqq_c(14) + 0.0751730429987 * X_glc__D_e(6)
# X_ppi_c*(0) =
# X_4cml_c*(7) =  + 1.80943061384e-06 * X_pqq_c(14) + 6.94757620875e-07 * X_glc__D_e(6)
# X_5odhf2a_c*(6) =  + 1.55094052614e-06 * X_pqq_c(14) + 5.95506532179e-07 * X_glc__D_e(6)
# X_4hbz_c*(7) =
# X_4hbz_e*(7) =
# X_4hbz_p*(7) =
# X_pi_c*(0) =
# X_phthr_c*(4) =
# X_4hthr_c*(4) =
# X_4mbzald_c*(8) =
# X_4mbzalc_c*(8) =
# X_p_tol_c*(8) =
# X_hmccms_c*(7) =
# X_4mcat_c*(7) =
# X_op4en_c*(5) =
# X_oxalc_c*(6) =
# X_2hchd_c*(6) =
# X_2omcm_c*(7) =
# X_2hmc_c*(6) =
# X_hmccm_c*(7) =
# X_chols_e*(5) =
# X_6hnac_c*(6) =
# X_dhpyr_c*(5) =
# X_L2aadp6sa_c*(6) =  + 2.25908322209e-07 * X_pqq_c(14) + 2.16509209506e-08 * X_glc__D_e(6)
# X_thp2c_c*(6) =  + 2.25908322209e-07 * X_pqq_c(14) + 2.16509209506e-08 * X_glc__D_e(6)
# X_L2aadp_c*(6) =  + 1.91785202395e-06 * X_pqq_c(14) + 1.45706851822e-07 * X_glc__D_e(6)
# X_glu__L_c*(5) =  + 2.85283175378 * X_pqq_c(14) + 1.20763965871 * X_glc__D_e(6)
# X_akg_c*(5) =
# X_2oxoadp_c*(6) =  + 7.37982827382e-08 * X_glc__D_e(6)
# X_sucsal_c*(4) =  + 0.00165526810735 * X_pqq_c(14)
# X_4abut_c*(4) =  + 0.0127137018591 * X_pqq_c(14) + 0.00229641446421 * X_glc__D_e(6)
# X_4abut_p*(4) =
# X_4abut_e*(4) =
# X_aacoa_c*(25) =  + 1.76819775767e-05 * X_pqq_c(14) + 1.40476733065e-06 * X_glc__D_e(6)
# X_acald_c*(2) =  + 0.126377667522 * X_pqq_c(14) + 1.32127015028e-07 * X_glc__D_e(6)
# X_adocbip_c*(58) =
# X_agdpcbi_c*(68) =
# X_gtp_c*(10) =  + 0.0189181377831 * X_pqq_c(14) + 0.00807096913824 * X_glc__D_e(6)
# X_hco3_c*(1) =
# X_malcoa_c*(24) =  + 0.0287761828858 * X_pqq_c(14) + 0.00538441130741 * X_glc__D_e(6)
# X_acglu_c*(7) =  + 0.466452443077 * X_pqq_c(14) + 0.0714520134894 * X_glc__D_e(6)
# X_acg5p_c*(7) =  + 0.00913019561197 * X_pqq_c(14) + 0.00270834937026 * X_glc__D_e(6)
# X_2ahbut_c*(6) =  + 2.67622932041e-06 * X_pqq_c(14) + 9.09232227699e-07 * X_glc__D_e(6)
# X_pyr_c*(3) =  + 0.159106221418 * X_pqq_c(14) + 0.0439107318346 * X_glc__D_e(6)
# X_2obut_c*(4) =  + 0.250436976904 * X_pqq_c(14) + 0.10654133229 * X_glc__D_e(6)
# X_ac_c*(2) =  + 8.03806649375 * X_pqq_c(14)
# X_actp_c*(2) =
# X_alac__S_c*(5) =  + 8.5988880307e-06 * X_pqq_c(14) + 2.37315337531e-06 * X_glc__D_e(6)
# X_fadh2_c*(27) =  + 4.31642428234e-06 * X_pqq_c(14) + 1.19181430967e-06 * X_glc__D_e(6)
# X_b2coa_c*(25) =  + 2.06065182093e-06 * X_pqq_c(14) + 6.01737507472e-07 * X_glc__D_e(6)
# X_fad_c*(27) =  + 2.42078987047e-06 * X_pqq_c(14) + 1.69277530018e-06 * X_glc__D_e(6)
# X_btcoa_c*(25) =
# X_hx2coa_c*(27) =
# X_hxcoa_c*(27) =
# X_oc2coa_c*(29) =
# X_occoa_c*(29) =
# X_dcacoa_c*(31) =
# X_dc2coa_c*(31) =
# X_ddcacoa_c*(33) =
# X_dd2coa_c*(33) =  + 4.05354551551e-08 * X_pqq_c(14) + 1.0439774978e-07 * X_glc__D_e(6)
# X_td2coa_c*(35) =
# X_tdcoa_c*(35) =
# X_pmtcoa_c*(37) =
# X_hdd2coa_c*(37) =
# X_2mb2coa_c*(26) =  + 1.78010430443e-06 * X_pqq_c(14) + 2.0180679751e-07 * X_glc__D_e(6)
# X_2mbcoa_c*(26) =  + 3.55931158261e-06 * X_pqq_c(14) + 3.6287252503e-07 * X_glc__D_e(6)
# X_ibcoa_c*(25) =  + 2.73307750789e-06 * X_pqq_c(14) + 2.62465857428e-07 * X_glc__D_e(6)
# X_2mp2coa_c*(25) =  + 2.73307750791e-06 * X_pqq_c(14) + 2.6246585743e-07 * X_glc__D_e(6)
# X_acACP_c*(0) =
# X_orn_c*(5) =
# X_acorn_c*(7) =
# X_acon_C_e*(6) =
# X_acon_C_p*(6) =
# X_icit_c*(6) =
# X_cit_c*(6) =  + 5.46580112235e-05 * X_pqq_c(14) + 7.73369747114e-06 * X_glc__D_e(6)
# X_acon_C_c*(6) =
# X_acg5sa_c*(7) =
# X_ppcoa_c*(24) =  + 6.50838010653e-06 * X_pqq_c(14) + 7.11259092058e-07 * X_glc__D_e(6)
# X_ppa_c*(3) =
# X_ac_p*(2) =
# X_ac_e*(2) =
# X_adn_c*(10) =  + 0.00806853523875 * X_pqq_c(14) + 0.00339059368716 * X_glc__D_e(6)
# X_nh4_c*(0) =
# X_ins_c*(10) =  + 0.0176433544853 * X_pqq_c(14) + 0.00745358609528 * X_glc__D_e(6)
# X_4abz_c*(7) =  + 4.18147351687e-07 * X_pqq_c(14) + 1.58329079256e-07 * X_glc__D_e(6)
# X_4adcho_c*(10) =  + 5.97353359553e-07 * X_pqq_c(14) + 2.26184398937e-07 * X_glc__D_e(6)
# X_adocbi_c*(58) =
# X_adcobhex_c*(55) =
# X_appl_c*(3) =
# X_applp_c*(3) =
# X_adcobdam_c*(55) =
# X_gln__L_c*(5) =  + 2.86141740683 * X_pqq_c(14) + 1.21531615265 * X_glc__D_e(6)
# X_camp_c*(10) =
# X_adocbl_c*(72) =
# X_rdmbzi_c*(14) =
# X_gmp_c*(10) =  + 0.00521746348297 * X_pqq_c(14) + 0.00221747239444 * X_glc__D_e(6)
# X_ade_c*(5) =  + 0.00471670854438 * X_pqq_c(14) + 0.00198207502868 * X_glc__D_e(6)
# X_prpp_c*(5) =  + 0.00755965189355 * X_pqq_c(14) + 0.00321604051518 * X_glc__D_e(6)
# X_C04051_c*(4) =
# X_aicar_c*(9) =  + 6.49313306378e-06 * X_pqq_c(14) + 2.57788059859e-06 * X_glc__D_e(6)
# X_fum_c*(4) =
# X_dcamp_c*(14) =  + 0.010255384844 * X_pqq_c(14) + 0.00442025052114 * X_glc__D_e(6)
# X_25aics_c*(13) =  + 6.20891246064e-06 * X_pqq_c(14) + 2.37554399239e-06 * X_glc__D_e(6)
# X_asp__L_c*(4) =
# X_4pasp_c*(4) =  + 0.00388938965106 * X_pqq_c(14) + 0.00170113464561 * X_glc__D_e(6)
# X_gdp_c*(10) =  + 0.0155952092886 * X_pqq_c(14) + 0.00668010609645 * X_glc__D_e(6)
# X_imp_c*(10) =  + 0.021024434545 * X_pqq_c(14) + 0.00892153843759 * X_glc__D_e(6)
# X_urea_c*(1) =  + 0.00231414640362 * X_pqq_c(14) + 0.00020824339188 * X_glc__D_e(6)
# X_ptrc_c*(4) =
# X_agm_c*(5) =  + 1.28742785467e-09 * X_pqq_c(14) + 5.54584716748e-10 * X_glc__D_e(6)
# X_pa120_c*(27) =
# X_1ddecg3p_c*(15) =
# X_1hdecg3p_c*(19) =
# X_pa160_c*(35) =
# X_1hdec9eg3p_c*(19) =
# X_pa161_c*(35) =
# X_1odecg3p_c*(21) =
# X_ocdcaACP_c*(0) =
# X_pa180_c*(39) =
# X_1odec11eg3p_c*(21) =
# X_pa181_c*(39) =
# X_octeACP_c*(0) =
# X_thf_c*(19) =  + 15.4952955838 * X_pqq_c(14) + 0.682986596146 * X_glc__D_e(6)
# X_fprica_c*(10) =  + 1.12445457204e-05 * X_pqq_c(14) + 1.35693712257e-06 * X_glc__D_e(6)
# X_10fthf_c*(20) =  + 1.53335600802 * X_pqq_c(14) + 0.0796876875829 * X_glc__D_e(6)
# X_5aizc_c*(9) =  + 6.82891539695e-06 * X_pqq_c(14) + 2.38510474486e-06 * X_glc__D_e(6)
# X_air_c*(8) =  + 5.56997903477e-06 * X_pqq_c(14) + 2.28882327891e-06 * X_glc__D_e(6)
# X_sdhlam_c*(12) =
# X_lpam_c*(8) =
# X_dhlam_c*(8) =  + 0.0051865881665 * X_pqq_c(14) + 0.000853407427636 * X_glc__D_e(6)
# X_akg_p*(5) =  + 3.98097906454e-06 * X_pqq_c(14) + 1.62031383895e-06 * X_glc__D_e(6)
# X_alaala_c*(6) =
# X_ala__D_c*(3) =
# X_ala__L_c*(3) =  + 0.00200574954446 * X_pqq_c(14) + 0.000676473512833 * X_glc__D_e(6)
# X_trnaala_c*(0) =
# X_alatrna_c*(0) =
# X_ala__L_p*(3) =
# X_ala__L_e*(3) =
# X_glyc_c*(3) =  + 0.312412864566 * X_pqq_c(14) + 0.010214467131 * X_glc__D_e(6)
# X_glyald_c*(3) =
# X_etoh_c*(2) =  + 0.0110213401776 * X_pqq_c(14) + 1.05701612022e-06 * X_glc__D_e(6)
# X_for_c*(1) =  + 0.0778986812424 * X_pqq_c(14) + 0.00404838745572 * X_glc__D_e(6)
# X_4ampm_c*(6) =
# X_r5p_c*(5) =  + 0.0345114064406 * X_pqq_c(14) + 0.00280340864355 * X_glc__D_e(6)
# X_anth_c*(7) =  + 4.79710297285e-07 * X_pqq_c(14) + 1.89871636898e-07 * X_glc__D_e(6)
# X_pran_c*(12) =  + 8.64294223473e-07 * X_pqq_c(14) + 3.53482012816e-07 * X_glc__D_e(6)
# X_chor_c*(10) =  + 5.37616254402e-06 * X_pqq_c(14) + 2.03565289148e-06 * X_glc__D_e(6)
# X_6a2ohxnt_c*(6) =
# X_ap4a_c*(20) =
# X_5apentam_c*(5) =
# X_5aptn_c*(5) =  + 1.32077518032e-06 * X_pqq_c(14) + 6.83615702775e-08 * X_glc__D_e(6)
# X_nh3_c*(0) =
# X_5aprbu_c*(9) =
# X_5apru_c*(9) =
# X_so3_c*(0) =
# X_trdrd_c*(0) =
# X_aps_c*(10) =  + 3.31969170091e-06 * X_pqq_c(14) + 1.41226899071e-06 * X_glc__D_e(6)
# X_trdox_c*(0) =
# X_oxptn_c*(5) =  + 3.2412971005e-07 * X_pqq_c(14)
# X_citr__L_c*(6) =  + 0.0232905372607 * X_pqq_c(14) + 0.00962121678162 * X_glc__D_e(6)
# X_arg__L_c*(6) =  + 0.0256731709593 * X_pqq_c(14) + 0.0110592202839 * X_glc__D_e(6)
# X_orn_p*(5) =
# X_arg__L_p*(6) =
# X_argsuc_c*(10) =  + 0.0427886182654 * X_pqq_c(14) + 0.0184320338066 * X_glc__D_e(6)
# X_argtrna_c*(0) =
# X_trnaarg_c*(0) =
# X_arg__L_e*(6) =
# X_5g2oxpt_c*(6) =  + 0.00401149908892 * X_pqq_c(14) + 0.00135294702567 * X_glc__D_e(6)
# X_aspsa_c*(4) =
# X_asn__L_c*(4) =  + 0.0276473772829 * X_pqq_c(14) + 0.0119352568312 * X_glc__D_e(6)
# X_cbp_c*(1) =  + 0.00733384046505 * X_pqq_c(14) + 0.0031189572786 * X_glc__D_e(6)
# X_cbasp_c*(5) =
# X_h2o2_c*(0) =
# X_oaa_c*(4) =  + 0.036431732951 * X_pqq_c(14) + 0.0140730562419 * X_glc__D_e(6)
# X_iasp_c*(4) =
# X_trnaasp_c*(0) =
# X_asptrna_c*(0) =
# X_asp__L_p*(4) =
# X_asp__L_e*(4) =
# X_sucarg_c*(10) =  + 0.00328829231085 * X_pqq_c(14) + 0.00032607042849 * X_glc__D_e(6)
# X_prbatp_c*(15) =  + 3.66199015108e-06 * X_pqq_c(14) + 1.55789024146e-06 * X_glc__D_e(6)
# X_bhb_c*(4) =
# X_acac_c*(4) =  + 6.54328450995e-07 * X_pqq_c(14) + 1.05717848653e-07 * X_glc__D_e(6)
# X_betald_c*(5) =
# X_glyb_c*(5) =
# X_hcys__L_c*(4) =  + 0.00346473313978 * X_pqq_c(14) + 0.000431690809615 * X_glc__D_e(6)
# X_dmgly_c*(4) =
# X_met__L_c*(5) =
# X_bz_c*(7) =
# X_bz12diol_c*(7) =
# X_bzalc_c*(7) =
# X_bzal_c*(7) =
# X_catechol_c*(6) =
# X_bz_p*(7) =
# X_bz_e*(7) =
# X_gly_c*(2) =  + 1.47528468193 * X_pqq_c(14) + 0.0637963492276 * X_glc__D_e(6)
# X_sheme_c*(42) =
# X_tyr__L_c*(9) =  + 1.36954210076e-07 * X_pqq_c(14)
# X_pg160_c*(38) =
# X_trp__L_c*(11) =  + 1.57449608688 * X_pqq_c(14) + 0.527095946032 * X_glc__D_e(6)
# X_lys__L_c*(6) =
# X_5mthf_c*(20) =  + 8.40702867796e-05 * X_pqq_c(14) + 5.25312123797e-06 * X_glc__D_e(6)
# X_cpe180_c*(43) =
# X_pg180_c*(42) =
# X_cpg160_c*(40) =
# X_pe181_c*(41) =
# X_pe120_c*(29) =
# X_ctp_c*(9) =  + 4.97936005281 * X_pqq_c(14) + 2.11717549378 * X_glc__D_e(6)
# X_cys__L_c*(3) =  + 0.00952852763059 * X_pqq_c(14) + 0.00118721345666 * X_glc__D_e(6)
# X_ile__L_c*(6) =
# X_pg120_c*(30) =
# X_pe160_c*(37) =
# X_dctp_c*(9) =  + 8.84782554048e-08 * X_pqq_c(14) + 3.68820137454e-08 * X_glc__D_e(6)
# X_val__L_c*(5) =
# X_utp_c*(9) =  + 4.97936183767 * X_pqq_c(14) + 2.11717625355 * X_glc__D_e(6)
# X_phe__L_c*(9) =
# X_leu__L_c*(6) =
# X_cpg180_c*(44) =
# X_dttp_c*(10) =  + 4.77330733233e-07 * X_pqq_c(14) + 1.34424704317e-07 * X_glc__D_e(6)
# X_datp_c*(10) =  + 3.49462812546e-07 * X_pqq_c(14) + 1.50900196973e-07 * X_glc__D_e(6)
# X_pro__L_c*(5) =  + 3.75376505497e-07 * X_pqq_c(14)
# X_pe161_c*(37) =
# X_his__L_c*(6) =  + 3.8450791647e-06 * X_pqq_c(14) + 3.53519375593e-07 * X_glc__D_e(6)
# X_cpe160_c*(39) =
# X_thr__L_c*(4) =  + 0.256803521975 * X_pqq_c(14) + 0.109249798917 * X_glc__D_e(6)
# X_ser__L_c*(3) =  + 0.00267917725549 * X_pqq_c(14) + 0.00058457841673 * X_glc__D_e(6)
# X_hemeO_c*(49) =
# X_udpg_c*(15) =
# X_dgtp_c*(10) =  + 3.07739621659e-07 * X_pqq_c(14) + 1.31289718761e-07 * X_glc__D_e(6)
# X_pe180_c*(41) =
# X_34dhbald_c*(7) =
# X_caffcoa_c*(30) =
# X_2hmcnsad_c*(6) =
# X_ccmuac_c*(6) =
# X_catechol_p*(6) =
# X_catechol_e*(6) =
# X_2p4c2me_c*(14) =
# X_4c2me_c*(14) =
# X_amet_c*(15) =
# X_ahcys_c*(14) =
# X_pg161_c*(38) =
# X_pg181_c*(42) =
# X_chol_c*(5) =
# X_chol_p*(5) =
# X_chol_e*(5) =
# X_so4_c*(0) =
# X_chols_c*(5) =
# X_chols_p*(5) =
# X_26dap__M_c*(7) =
# X_26dap_LL_c*(7) =
# X_pphn_c*(10) =  + 4.13366755821e-06 * X_pqq_c(14) + 1.56518934247e-06 * X_glc__D_e(6)
# X_3psme_c*(10) =  + 5.37616254401e-06 * X_pqq_c(14) + 2.03565289148e-06 * X_glc__D_e(6)
# X_cit_p*(6) =
# X_clpn120_p*(57) =
# X_pg120_p*(30) =
# X_glyc_p*(3) =  + 9.0096409817e-06 * X_pqq_c(14) + 2.94573918386e-07 * X_glc__D_e(6)
# X_clpn160_p*(73) =
# X_pg160_p*(38) =
# X_pg161_p*(38) =
# X_clpn161_p*(73) =
# X_clpn180_p*(81) =
# X_pg180_p*(42) =
# X_pg181_p*(42) =
# X_clpn181_p*(81) =
# X_co2_p*(1) =
# X_confrl_c*(10) =
# X_conialdh_c*(10) =
# X_fer_c*(10) =
# X_cobalt2_p*(0) =
# X_cobalt2_e*(0) =
# X_cobalt2_c*(0) =
# X_co2dam_c*(45) =
# X_hgbam_c*(45) =
# X_4hbald_c*(7) =
# X_confrl_e*(10) =
# X_confrl_p*(10) =
# X_pppg9_c*(34) =
# X_cpppg3_c*(36) =
# X_dad_5_c*(10) =
# X_crn_c*(7) =
# X_crn_p*(7) =
# X_crn_e*(7) =
# X_csn_c*(4) =
# X_ura_c*(4) =  + 0.0697987218902 * X_pqq_c(14) + 0.0296939195998 * X_glc__D_e(6)
# X_q8h2_c*(49) =  + 0.00701211244659 * X_pqq_c(14) + 4.63946378563 * X_glc__D_e(6)
# X_focytc_c*(42) =  + 6.99287452731e-05 * X_pqq_c(14) + 0.0462673529183 * X_glc__D_e(6)
# X_q8_c*(49) =  + 0.00701211244658 * X_pqq_c(14) + 4.63946378562 * X_glc__D_e(6)
# X_ficytc_c*(42) =  + 6.99287452731e-05 * X_pqq_c(14) + 0.0462673529183 * X_glc__D_e(6)
# X_co1dam_c*(45) =
# X_pppi_c*(0) =
# X_acser_c*(5) =  + 0.0158808793843 * X_pqq_c(14) + 0.00197868909444 * X_glc__D_e(6)
# X_h2s_c*(0) =
# X_scys__L_c*(3) =
# X_tsul_c*(0) =
# X_cyst__L_c*(7) =  + 3.27011986774 * X_pqq_c(14) + 0.407442835074 * X_glc__D_e(6)
# X_cystrna_c*(0) =
# X_trnacys_c*(0) =
# X_cys__L_p*(3) =
# X_cys__L_e*(3) =
# X_cdp_c*(9) =
# X_cmp_c*(9) =
# X_dcmp_c*(9) =
# X_dcdp_c*(9) =
# X_24dab_c*(4) =
# X_dad_2_c*(10) =
# X_din_c*(10) =
# X_damp_c*(10) =
# X_dadp_c*(10) =  + 3.47098899981e-07 * X_pqq_c(14) + 1.52125659439e-07 * X_glc__D_e(6)
# X_pprdn_c*(5) =
# X_15dap_c*(5) =
# X_cdpdddecg_c*(36) =
# X_cdpdhdecg_c*(44) =
# X_cdpdhdec9eg_c*(44) =
# X_cdpdodecg_c*(48) =
# X_cdpdodec11eg_c*(48) =
# X_db4p_c*(4) =
# X_ru5p__D_c*(5) =  + 0.014978218637 * X_glc__D_e(6)
# X_dca_e*(10) =
# X_dca_p*(10) =
# X_dutp_c*(9) =  + 3.05802669903e-07 * X_pqq_c(14) + 1.3006248357e-07 * X_glc__D_e(6)
# X_ddca_p*(12) =
# X_ddca_e*(12) =
# X_e4p_c*(4) =
# X_pep_c*(3) =  + 0.0116667941817 * X_pqq_c(14) + 0.00447963801813 * X_glc__D_e(6)
# X_2dda7p_c*(7) =  + 3.91738905542e-06 * X_pqq_c(14) + 1.50413941235e-06 * X_glc__D_e(6)
# X_dgmp_c*(10) =
# X_dgdp_c*(10) =  + 2.53681720331e-07 * X_pqq_c(14) + 1.08662908921e-07 * X_glc__D_e(6)
# X_dh3mchc_c*(8) =
# X_dh4mchc_c*(8) =
# X_23dhmb_c*(5) =
# X_3mob_c*(5) =
# X_23dhmp_c*(6) =  + 1.34694926486e-06 * X_pqq_c(14) + 2.74145044652e-07 * X_glc__D_e(6)
# X_3mop_c*(6) =  + 1.34694926486e-06 * X_pqq_c(14) + 2.74145044652e-07 * X_glc__D_e(6)
# X_thdp_c*(7) =  + 1.78871798903e-06 * X_pqq_c(14) + 2.81862370217e-07 * X_glc__D_e(6)
# X_23dhdp_c*(7) =  + 1.77682970183e-06 * X_pqq_c(14) + 6.1202106912e-07 * X_glc__D_e(6)
# X_dhf_c*(19) =  + 2.87077656896e-06 * X_pqq_c(14) + 6.86644479775e-07 * X_glc__D_e(6)
# X_dhpt_c*(14) =  + 8.42209246422e-07 * X_pqq_c(14) + 3.39244811627e-07 * X_glc__D_e(6)
# X_dhnpt_c*(9) =  + 5.45207991784e-07 * X_pqq_c(14) + 2.32599895723e-07 * X_glc__D_e(6)
# X_gcald_c*(2) =  + 1.21157331508e-07 * X_pqq_c(14) + 5.16888657161e-08 * X_glc__D_e(6)
# X_2ahhmp_c*(7) =  + 4.24050660276e-07 * X_pqq_c(14) + 1.80911030006e-07 * X_glc__D_e(6)
# X_dhor__S_c*(5) =  + 1.31726244305e-06 * X_pqq_c(14) + 5.27683569358e-07 * X_glc__D_e(6)
# X_orot_c*(5) =  + 1.31726244305e-06 * X_pqq_c(14) + 5.27683569358e-07 * X_glc__D_e(6)
# X_2dhphaccoa_c*(29) =
# X_3hadpcoa_c*(27) =
# X_h2_c*(0) =
# X_56dura_c*(4) =
# X_cala_c*(4) =
# X_25dhpp_c*(9) =
# X_dhbpt_c*(9) =  + 1.36954210076e-07 * X_pqq_c(14)
# X_thbpt_c*(9) =  + 3.64589882337e-07 * X_pqq_c(14) + 6.1019078419e-09 * X_glc__D_e(6)
# X_3dhq_c*(7) =  + 3.91738905542e-06 * X_pqq_c(14) + 1.50413941235e-06 * X_glc__D_e(6)
# X_3dhsk_c*(7) =  + 3.91738905542e-06 * X_pqq_c(14) + 1.50413941235e-06 * X_glc__D_e(6)
# X_lys__D_c*(6) =
# X_glu__D_c*(5) =
# X_ipdp_c*(5) =
# X_grdp_c*(10) =
# X_dmpp_c*(5) =
# X_sarcs_c*(3) =
# X_aacald_c*(2) =
# X_ptal_c*(5) =
# X_dhpmp_c*(9) =  + 5.45207991784e-07 * X_pqq_c(14) + 2.32599895723e-07 * X_glc__D_e(6)
# X_ahdt_c*(9) =  + 5.45207991784e-07 * X_pqq_c(14) + 2.32599895723e-07 * X_glc__D_e(6)
# X_dpcoa_c*(21) =
# X_2dhp_c*(6) =
# X_pant__R_c*(6) =
# X_dtmp_c*(10) =  + 8.53842757599e-07 * X_pqq_c(14) + 8.86746137494e-08 * X_glc__D_e(6)
# X_dtdp_c*(10) =  + 6.02834741355e-07 * X_pqq_c(14) + 1.19174674128e-07 * X_glc__D_e(6)
# X_dump_c*(9) =  + 3.05802669903e-07 * X_pqq_c(14) + 1.3006248357e-07 * X_glc__D_e(6)
# X_2me4p_c*(5) =
# X_dxyl5p_c*(5) =
# X_g3p_c*(3) =  + 0.36022051743 * X_pqq_c(14) + 0.148891368384 * X_glc__D_e(6)
# X_lac__D_p*(3) =  + 1.79635770124e-07 * X_pqq_c(14) + 7.56403384566e-09 * X_glc__D_e(6)
# X_lac__D_c*(3) =
# X_4per_c*(4) =
# X_3hbcoa_c*(25) =
# X_3hhcoa_c*(27) =
# X_3hocoa_c*(29) =  + 6.79094556439e-07 * X_pqq_c(14) + 6.15403237517e-08 * X_glc__D_e(6)
# X_3hdcoa_c*(31) =  + 2.27675957563e-06 * X_pqq_c(14) + 2.01371916649e-07 * X_glc__D_e(6)
# X_3hddcoa_c*(33) =
# X_3htdcoa_c*(35) =
# X_3hhdcoa_c*(37) =
# X_3hmbcoa_c*(26) =  + 1.78010430443e-06 * X_pqq_c(14) + 2.0180679751e-07 * X_glc__D_e(6)
# X_2ddg6p_c*(6) =  + 0.00268291063496 * X_glc__D_e(6)
# X_6pgc_c*(6) =  + 0.117509906512 * X_glc__D_e(6)
# X_2pg_c*(3) =
# X_ethso3_p*(2) =
# X_ethso3_c*(2) =
# X_ethso3_e*(2) =
# X_2ddglcn_e*(6) =
# X_T4hcinnm_e*(9) =
# X_fe2_e*(0) =
# X_fer_e*(10) =
# X_fru_e*(6) =
# X_fum_e*(4) =
# X_ga_e*(7) =
# X_glu__L_e*(5) =
# X_glyb_e*(5) =
# X_h2_e*(0) =
# X_h2o_e*(0) =
# X_h_e*(0) =
# X_hco3_e*(1) =
# X_hdca_e*(16) =
# X_his__L_e*(6) =
# X_hxa_e*(6) =
# X_ile__L_e*(6) =
# X_isetac_e*(2) =
# X_lac__L_e*(3) =
# X_leu__L_e*(6) =
# X_lys__L_e*(6) =
# X_m_xyl_e*(8) =
# X_mal__L_e*(4) =
# X_met__L_e*(5) =
# X_mso3_e*(1) =
# X_na1_e*(0) =
# X_nac_e*(6) =
# X_ni2_e*(0) =
# X_no2_e*(0) =
# X_octa_e*(8) =
# X_orn_e*(5) =
# X_p_xyl_e*(8) =
# X_pac_e*(8) =
# X_pentso3_e*(5) =
# X_pro__L_e*(5) =
# X_ptrc_e*(4) =
# X_quin_e*(7) =
# X_rib__D_e*(5) =
# X_spmd_e*(7) =
# X_succ_e*(4) =
# X_taur_e*(2) =
# X_thr__L_e*(4) =
# X_tol_e*(7) =
# X_tsul_e*(0) =
# X_ttdca_e*(14) =
# X_val__L_e*(5) =
# X_vanln_e*(8) =
# X_vanlt_e*(8) =
# X_ttdca_p*(14) =
# X_hdca_p*(16) =
# X_hxa_p*(6) =
# X_octa_p*(8) =
# X_cytcc_c*(42) =
# X_fdp_c*(6) =
# X_dhap_c*(3) =  + 9.17474597732e-09 * X_pqq_c(14) + 2.79212051456e-09 * X_glc__D_e(6)
# X_f6p_c*(6) =
# X_fe2_c*(0) =
# X_pheme_c*(34) =
# X_ppp9_c*(34) =
# X_ferulcoa_c*(31) =
# X_vanln_c*(8) =
# X_isetac_c*(2) =
# X_fmnh2_c*(17) =  + 3.03613718904e-06 * X_pqq_c(14) + 2.86438518545e-07 * X_glc__D_e(6)
# X_fmn_c*(17) =  + 2.77442492099e-06 * X_pqq_c(14) + 2.55744119951e-07 * X_glc__D_e(6)
# X_mso3_c*(1) =
# X_pentso3_c*(5) =
# X_taur_c*(2) =
# X_fer_p*(10) =
# X_mettrna_c*(0) =
# X_fmettrna_c*(0) =
# X_2ahhmd_c*(7) =  + 1.19958459033e-10 * X_pqq_c(14)
# X_forglu_c*(6) =  + 1.82600509058e-06 * X_pqq_c(14) + 1.67884236397e-07 * X_glc__D_e(6)
# X_Nforglu_c*(6) =  + 1.82600509058e-06 * X_pqq_c(14) + 1.67884236397e-07 * X_glc__D_e(6)
# X_f1p_c*(6) =
# X_mal__L_c*(4) =  + 0.0151929661119 * X_pqq_c(14) + 0.00167407938614 * X_glc__D_e(6)
# X_4fumacac_c*(8) =  + 4.9545399229e-07 * X_pqq_c(14) + 5.57958769369e-08 * X_glc__D_e(6)
# X_fum_p*(4) =
# X_acgam1p_c*(8) =
# X_gam1p_c*(6) =
# X_glu1sa_c*(5) =  + 1.96973754089e-08 * X_pqq_c(14) + 1.88778489319e-09 * X_glc__D_e(6)
# X_5aop_c*(5) =  + 1.96973754089e-08 * X_pqq_c(14) + 1.88778489319e-09 * X_glc__D_e(6)
# X_glyc3p_c*(3) =  + 0.141185818452 * X_pqq_c(14) + 0.0317506192569 * X_glc__D_e(6)
# X_glu5sa_c*(5) =  + 0.00137663760734 * X_pqq_c(14) + 0.000316077497997 * X_glc__D_e(6)
# X_1pyr5c_c*(5) =  + 0.00137671722522 * X_pqq_c(14) + 0.000316101982248 * X_glc__D_e(6)
# X_glu5p_c*(5) =  + 0.00291145140852 * X_pqq_c(14) + 0.00123656685529 * X_glc__D_e(6)
# X_6pgl_c*(6) =
# X_g6p_B_c*(6) =
# X_g6p_c*(6) =
# X_omaketo_c*(7) =
# X_ga_c*(7) =
# X_glcn_p*(6) =  + 0.000377934476083 * X_pqq_c(14) + 0.347691234573 * X_glc__D_e(6)
# X_g1p_c*(6) =
# X_13dpg_c*(3) =
# X_fgam_c*(8) =  + 0.00803322730706 * X_pqq_c(14) + 0.00275040597509 * X_glc__D_e(6)
# X_gar_c*(7) =  + 6.32302092504e-06 * X_pqq_c(14) + 1.87865904147e-06 * X_glc__D_e(6)
# X_ga_p*(7) =
# X_glyclt_c*(2) =  + 3.82244468163e-07 * X_pqq_c(14) + 3.25364159292e-08 * X_glc__D_e(6)
# X_gdbtal_c*(5) =  + 0.00334291590743 * X_pqq_c(14) + 0.00112745585472 * X_glc__D_e(6)
# X_4gudbutn_c*(5) =  + 0.0115707307307 * X_pqq_c(14) + 0.00104121640481 * X_glc__D_e(6)
# X_gam6p_c*(6) =
# X_mlthf_c*(20) =  + 13.7667181425 * X_pqq_c(14) + 0.806170820306 * X_glc__D_e(6)
# X_h2o_p*(0) =
# X_glc__D_p*(6) =  + 0.999999999997 * X_glc__D_e(6)
# X_glcn_c*(6) =  + 0.000362870913401 * X_pqq_c(14) + 0.333833095034 * X_glc__D_e(6)
# X_glutar_c*(5) =  + 1.63669381714e-06 * X_pqq_c(14) + 9.90234963499e-08 * X_glc__D_e(6)
# X_glutcoa_c*(26) =  + 7.23235719864e-06 * X_pqq_c(14) + 1.3746623126e-06 * X_glc__D_e(6)
# X_S_gtrdhdlp_c*(13) =  + 6.85269768283e-08 * X_glc__D_e(6)
# X_glc__D_c*(6) =  + 1.09573032408e-05 * X_pqq_c(14) + 0.0393798783011 * X_glc__D_e(6)
# X_glutrna_gln_c*(0) =
# X_glntrna_c*(0) =
# X_trnagln_c*(0) =
# X_glucys_c*(8) =
# X_pram_c*(5) =  + 3.39594091058e-06 * X_pqq_c(14) + 1.44352722197e-06 * X_glc__D_e(6)
# X_trnaglu_c*(0) =
# X_glutrna_c*(0) =
# X_glu__L_p*(5) =
# X_na1_p*(0) =
# X_na1_c*(0) =
# X_2h3oppan_c*(3) =  + 1.8554498845e-08 * X_pqq_c(14) + 1.57934762185e-09 * X_glc__D_e(6)
# X_glx_c*(2) =  + 2.55863566177e-08 * X_pqq_c(14) + 2.1778950655e-09 * X_glc__D_e(6)
# X_glyc__R_c*(3) =
# X_glyald_p*(3) =  + 1.29897799623e-07 * X_pqq_c(14) + 4.24706199751e-09 * X_glc__D_e(6)
# X_glyb_p*(5) =
# X_3pg_c*(3) =  + 0.0342039807259 * X_pqq_c(14) + 0.014551116697 * X_glc__D_e(6)
# X_glyclt_p*(2) =
# X_hpyr_c*(3) =
# X_trnagly_c*(0) =
# X_glytrna_c*(0) =
# X_gly_p*(2) =
# X_xmp_c*(10) =  + 8.77868812106e-06 * X_pqq_c(14) + 1.04625892099e-06 * X_glc__D_e(6)
# X_gua_c*(5) =  + 0.00260674746597 * X_pqq_c(14) + 0.00110789286095 * X_glc__D_e(6)
# X_gsn_c*(10) =  + 0.00521349493195 * X_pqq_c(14) + 0.00221578572191 * X_glc__D_e(6)
# X_rib__D_c*(5) =  + 0.0114284247086 * X_pqq_c(14) + 0.00483468590859 * X_glc__D_e(6)
# X_frdp_c*(15) =
# X_gthox_c*(20) =  + 3.88466115604e-08 * X_pqq_c(14) + 3.72303644181e-09 * X_glc__D_e(6)
# X_gthrd_c*(10) =  + 3.88466115583e-08 * X_pqq_c(14) + 3.72303644161e-09 * X_glc__D_e(6)
# X_gdptp_c*(10) =  + 0.00826596728891 * X_pqq_c(14) + 0.00352109741802 * X_glc__D_e(6)
# X_ppgpp_c*(10) =  + 0.00826596728891 * X_pqq_c(14) + 0.00352109741802 * X_glc__D_e(6)
# X_xan_c*(5) =
# X_h2co3_c*(1) =
# X_h2_p*(0) =
# X_3ohcoa_c*(27) =  + 1.14879973967e-06 * X_pqq_c(14) + 8.66654565962e-08 * X_glc__D_e(6)
# X_3oocoa_c*(29) =  + 1.52519942462e-06 * X_pqq_c(14) + 1.210405184e-07 * X_glc__D_e(6)
# X_3odcoa_c*(31) =  + 5.64611551656e-06 * X_pqq_c(14) + 4.43596978114e-07 * X_glc__D_e(6)
# X_3oddcoa_c*(33) =  + 1.28659130865e-05 * X_pqq_c(14) + 9.08674680465e-07 * X_glc__D_e(6)
# X_3otdcoa_c*(35) =
# X_3ohdcoa_c*(37) =
# X_2maacoa_c*(26) =  + 3.41272090262e-06 * X_pqq_c(14) + 2.94804800406e-07 * X_glc__D_e(6)
# X_4mlacac_c*(8) =  + 4.9545399229e-07 * X_pqq_c(14) + 5.57958769369e-08 * X_glc__D_e(6)
# X_mmtsa_c*(4) =  + 6.54993806092e-07 * X_pqq_c(14) + 5.08535666384e-08 * X_glc__D_e(6)
# X_urcan_c*(6) =  + 1.82600509062e-06 * X_pqq_c(14) + 1.67884236401e-07 * X_glc__D_e(6)
# X_histd_c*(6) =  + 1.45463591621e-06 * X_pqq_c(14) + 6.17310452744e-07 * X_glc__D_e(6)
# X_hisp_c*(6) =  + 1.45463591621e-06 * X_pqq_c(14) + 6.17310452744e-07 * X_glc__D_e(6)
# X_histrna_c*(0) =
# X_trnahis_c*(0) =
# X_his__L_p*(6) =
# X_ppbng_c*(10) =
# X_hmbil_c*(40) =
# X_hmgcoa_c*(27) =  + 2.74455982024e-06 * X_pqq_c(14) + 5.25284393742e-07 * X_glc__D_e(6)
# X_4ahmmp_c*(6) =
# X_4h2opntn_c*(5) =
# X_ppal_c*(3) =
# X_4hoxoh_c*(6) =
# X_hom__L_c*(4) =
# X_achms_c*(6) =
# X_phom_c*(4) =  + 0.256803521975 * X_pqq_c(14) + 0.109249798917 * X_glc__D_e(6)
# X_imacp_c*(6) =  + 1.46310347094e-06 * X_pqq_c(14) + 6.22182146163e-07 * X_glc__D_e(6)
# X_hxan_c*(5) =  + 0.00882167724266 * X_pqq_c(14) + 0.00372679304764 * X_glc__D_e(6)
# X_icit_p*(6) =
# X_prlp_c*(15) =  + 3.66199015108e-06 * X_pqq_c(14) + 1.55789024146e-06 * X_glc__D_e(6)
# X_eig3p_c*(6) =  + 1.46310347094e-06 * X_pqq_c(14) + 6.22182146163e-07 * X_glc__D_e(6)
# X_3ig3p_c*(11) =  + 7.92269704851e-07 * X_pqq_c(14) + 3.24025178415e-07 * X_glc__D_e(6)
# X_2cpr5p_c*(12) =  + 8.64294223473e-07 * X_pqq_c(14) + 3.53482012816e-07 * X_glc__D_e(6)
# X_trnaile_c*(0) =
# X_iletrna_c*(0) =
# X_ile__L_p*(6) =
# X_h2mb4p_c*(5) =
# X_3c2hmp_c*(7) =  + 5.0340669735e-06 * X_pqq_c(14) + 5.22025323147e-07 * X_glc__D_e(6)
# X_3c4mop_c*(7) =  + 1.19153751939e-05 * X_pqq_c(14) + 9.34459771585e-07 * X_glc__D_e(6)
# X_2ippm_c*(7) =
# X_3c3hmp_c*(7) =  + 5.03406697388e-06 * X_pqq_c(14) + 5.22025323186e-07 * X_glc__D_e(6)
# X_isetac_p*(2) =
# X_4izp_c*(6) =  + 1.82600509058e-06 * X_pqq_c(14) + 1.67884236397e-07 * X_glc__D_e(6)
# X_4mop_c*(6) =  + 1.02131787377e-05 * X_pqq_c(14) + 8.00965518501e-07 * X_glc__D_e(6)
# X_leutrna_c*(0) =
# X_trnaleu_c*(0) =
# X_leu__L_p*(6) =
# X_trnalys_c*(0) =
# X_lystrna_c*(0) =
# X_lys__L_p*(6) =
# X_lac__L_c*(3) =
# X_lac__L_p*(3) =
# X_male_c*(4) =
# X_malm_c*(4) =
# X_mal__L_p*(4) =
# X_3mb2coa_c*(26) =  + 2.75534002672e-06 * X_pqq_c(14) + 2.91977567087e-07 * X_glc__D_e(6)
# X_ivcoa_c*(26) =  + 5.52125808756e-06 * X_pqq_c(14) + 5.28477480035e-07 * X_glc__D_e(6)
# X_3mgcoa_c*(27) =  + 2.74455982024e-06 * X_pqq_c(14) + 5.25284393743e-07 * X_glc__D_e(6)
# X_2mcit_c*(7) =  + 2.48571941416e-06 * X_pqq_c(14) + 3.30429975482e-07 * X_glc__D_e(6)
# X_2mcacn_c*(7) =  + 2.48571941416e-06 * X_pqq_c(14) + 3.30429975482e-07 * X_glc__D_e(6)
# X_micit_c*(7) =
# X_2mecdp_c*(5) =
# X_ch4s_c*(1) =
# X_trnamet_c*(0) =
# X_met__L_p*(5) =
# X_mso3_p*(1) =
# X_methf_c*(20) =  + 1.53335600802 * X_pqq_c(14) + 0.0796876875829 * X_glc__D_e(6)
# X_mhpglu_c*(25) =
# X_hpglu_c*(24) =
# X_mucl_c*(6) =
# X_CCbuttc_c*(7) =  + 1.80943061384e-06 * X_pqq_c(14) + 6.94757620875e-07 * X_glc__D_e(6)
# X_m_xyl_c*(8) =
# X_m_xyl_p*(8) =
# X_nac_c*(6) =
# X_nac_p*(6) =
# X_dnad_c*(21) =
# X_nicrnt_c*(11) =
# X_udp_c*(9) =  + 4.03927635631e-06 * X_pqq_c(14) + 1.71839666679e-06 * X_glc__D_e(6)
# X_dudp_c*(9) =  + 3.01988111756e-07 * X_pqq_c(14) + 1.2847235962e-07 * X_glc__D_e(6)
# X_nfmalm_c*(5) =
# X_nh4_p*(0) =
# X_ni2_p*(0) =
# X_ni2_c*(0) =
# X_5prdmbz_c*(14) =
# X_dmbzid_c*(9) =
# X_quln_c*(7) =
# X_no2_p*(0) =
# X_no2_c*(0) =
# X_xtsn_c*(10) =
# X_xmp_p*(10) =
# X_pi_p*(0) =
# X_xtsn_p*(10) =
# X_imp_p*(10) =
# X_ins_p*(10) =
# X_ump_c*(9) =  + 0.157051163331 * X_pqq_c(14) + 0.0668130374126 * X_glc__D_e(6)
# X_uri_c*(9) =  + 0.157047124253 * X_pqq_c(14) + 0.0668113190996 * X_glc__D_e(6)
# X_uri_p*(9) =
# X_ump_p*(9) =
# X_dcyt_c*(9) =
# X_dcyt_p*(9) =
# X_dcmp_p*(9) =
# X_cytd_c*(9) =
# X_cytd_p*(9) =
# X_cmp_p*(9) =
# X_thymd_c*(10) =
# X_dtmp_p*(10) =
# X_thymd_p*(10) =
# X_damp_p*(10) =
# X_dad_2_p*(10) =
# X_adn_p*(10) =
# X_amp_p*(10) =
# X_dgsn_c*(10) =
# X_dgmp_p*(10) =
# X_dgsn_p*(10) =
# X_gmp_p*(10) =
# X_gsn_p*(10) =
# X_o2_p*(0) =
# X_oca_c*(7) =
# X_ohpb_c*(4) =
# X_omaenol_c*(7) =
# X_orot5p_c*(10) =
# X_phaccoa_c*(29) =
# X_pac_c*(8) =
# X_pac_p*(8) =
# X_pnto__R_c*(9) =
# X_ala_B_c*(3) =
# X_uagmda_c*(87) =
# X_ugmda_c*(41) =
# X_udcpp_c*(55) =
# X_pre4_c*(44) =
# X_pre5_c*(45) =
# X_pre3b_c*(43) =
# X_pre3a_c*(43) =
# X_dscl_c*(42) =
# X_pre6b_c*(44) =
# X_pre6a_c*(44) =
# X_pre8_c*(45) =
# X_hgbyr_c*(45) =
# X_adhlam_c*(10) =  + 0.00230409328454 * X_pqq_c(14) + 0.000635892307904 * X_glc__D_e(6)
# X_pdx5p_c*(8) =
# X_pydx5p_c*(8) =
# X_pydxn_c*(8) =
# X_pe120_p*(29) =
# X_pe160_p*(37) =
# X_pe161_p*(37) =
# X_pe180_p*(41) =
# X_pe181_p*(41) =
# X_pentso3_p*(5) =
# X_3php_c*(3) =  + 0.00437620177033 * X_pqq_c(14) + 0.000386847664805 * X_glc__D_e(6)
# X_pgp120_c*(30) =
# X_pgp120_p*(30) =
# X_pgp160_c*(38) =
# X_pgp160_p*(38) =
# X_pgp161_p*(38) =
# X_pgp161_c*(38) =
# X_pgp180_c*(42) =
# X_pgp180_p*(42) =
# X_pgp181_p*(42) =
# X_pgp181_c*(42) =
# X_phpyr_c*(9) =  + 2.07167430705e-06 * X_pqq_c(14) + 7.8442750918e-07 * X_glc__D_e(6)
# X_phetrna_c*(0) =
# X_trnaphe_c*(0) =
# X_phe__L_p*(9) =  + 9.98268282235e-08 * X_pqq_c(14) + 3.9560658193e-08 * X_glc__D_e(6)
# X_4r5au_c*(9) =
# X_2mahmp_c*(6) =
# X_4ppan_c*(9) =
# X_pan4p_c*(11) =
# X_4ppcys_c*(12) =
# X_r1p_c*(5) =  + 0.0872484023628 * X_pqq_c(14) + 0.0371173994998 * X_glc__D_e(6)
# X_udcpdp_c*(55) =
# X_peptido_kt_c*(40) =
# X_uaagmda_c*(95) =
# X_fpram_c*(8) =  + 5.72479128478e-06 * X_pqq_c(14) + 2.25372521779e-06 * X_glc__D_e(6)
# X_prbamp_c*(15) =  + 3.66199015108e-06 * X_pqq_c(14) + 1.55789024146e-06 * X_glc__D_e(6)
# X_prfp_c*(15) =  + 3.66199015108e-06 * X_pqq_c(14) + 1.55789024146e-06 * X_glc__D_e(6)
# X_protrna_c*(0) =
# X_trnapro_c*(0) =
# X_pro__L_p*(5) =
# X_skm5p_c*(7) =  + 3.32908448843e-06 * X_pqq_c(14) + 1.24964702379e-06 * X_glc__D_e(6)
# X_ps120_c*(30) =
# X_ps160_c*(38) =
# X_ps161_c*(38) =
# X_ps180_c*(42) =
# X_ps181_c*(42) =
# X_pser__L_c*(3) =  + 0.00267964591518 * X_pqq_c(14) + 0.000584707759189 * X_glc__D_e(6)
# X_ptrc_p*(4) =
# X_p_xyl_c*(8) =
# X_pydx_c*(8) =
# X_p_xyl_p*(8) =
# X_quin_c*(7) =
# X_quin_p*(7) =
# X_r15bp_c*(5) =  + 0.00755949496067 * X_pqq_c(14) + 0.0032159743901 * X_glc__D_e(6)
# X_ribflv_c*(17) =
# X_dmlz_c*(13) =
# X_rib__D_p*(5) =
# X_rbrdxOX_c*(0) =
# X_rbrdxRD_c*(0) =
# X_xu5p__D_c*(5) =
# X_sucorn_c*(9) =  + 0.00295946307976 * X_pqq_c(14) + 0.000293463385641 * X_glc__D_e(6)
# X_sl26da_c*(11) =
# X_sl2a6o_c*(11) =  + 1.17270316303e-05 * X_pqq_c(14) + 9.86298788126e-07 * X_glc__D_e(6)
# X_seasmet_c*(15) =
# X_selmeth_c*(5) =
# X_sertrna_c*(0) =
# X_trnaser_c*(0) =
# X_ser__L_p*(3) =
# X_sucglu_c*(9) =  + 0.00397683407442 * X_pqq_c(14) + 0.000300012377235 * X_glc__D_e(6)
# X_sucgsa_c*(9) =
# X_scl_c*(42) =
# X_skm_c*(7) =  + 1.67514192197e-06 * X_pqq_c(14) + 3.07998395397e-07 * X_glc__D_e(6)
# X_suchms_c*(8) =
# X_so4_p*(0) =
# X_spmd_c*(7) =
# X_spmd_p*(7) =
# X_5mta_c*(11) =
# X_ametam_c*(14) =
# X_succ_p*(4) =
# X_T4hcinnm_p*(9) =
# X_s7p_c*(7) =
# X_taur_p*(2) =
# X_athr__L_c*(4) =
# X_trnathr_c*(0) =
# X_thrtrna_c*(0) =
# X_thr__L_p*(4) =
# X_tol_p*(7) =
# X_tol_c*(7) =
# X_indole_c*(8) =  + 0.962059608227 * X_pqq_c(14) + 0.393466434843 * X_glc__D_e(6)
# X_tsul_p*(0) =
# X_tyrtrna_c*(0) =
# X_trnatyr_c*(0) =
# X_tyr__L_p*(9) =  + 1.98492776743e-08 * X_glc__D_e(6)
# X_uamag_c*(28) =
# X_ugmd_c*(35) =
# X_uacgam_c*(17) =
# X_uaccg_c*(20) =
# X_uama_c*(23) =
# X_uamr_c*(20) =
# X_2kmb_c*(5) =
# X_uppg3_c*(40) =
# X_uppg1_c*(40) =
# X_cpppg1_c*(36) =
# X_valtrna_c*(0) =
# X_trnaval_c*(0) =
# X_val__L_p*(5) =
# X_vanlt_c*(8) =
# X_vanlt_p*(8) =
# X_vanln_p*(8) =
# X_urate_c*(5) =
# X_cit_e*(6) =  + 1.22850754209e-07 * X_pqq_c(14) + 1.73824576834e-08 * X_glc__D_e(6)
# X_2dhglcn_e*(6) =
# X_3oxoadp_e*(6) =  + 1.48833674721e-06 * X_pqq_c(14) + 5.71468886206e-07 * X_glc__D_e(6)
# X_34dhbz_e*(7) =  + 6.08803862223e-08 * X_pqq_c(14) + 2.3375923877e-08 * X_glc__D_e(6)
# X_akg_e*(5) =
# X_pqqh2_c*(14) =  + 0.884643672655 * X_pqq_c(14) + 9.24889105192e-07 * X_glc__D_e(6)
# X_fald_c*(1) =  + 1.63201465941e-07 * X_pqq_c(14) + 1.50437717618e-08 * X_glc__D_e(6)
# X_C100mclPHA_c*(0) =
# X_C120mclPHA_c*(0) =
# X_C121mclPHA_c*(0) =
# X_C140mclPHA_c*(0) =
# X_C141mclPHA_c*(0) =
# X_C60mclPHA_c*(0) =
# X_C80mclPHA_c*(0) =
# X_mclPHA_c*(0) =
# X_dna_c*(0) =
# X_lac__D_e*(3) =
# X_glcn_e*(6) =
# X_gly_e*(2) =  + 0.000150113144955 * X_pqq_c(14) + 4.00481944487e-05 * X_glc__D_e(6)
# X_glyald_e*(3) =
# X_glyc_e*(3) =
# X_glyclt_e*(2) =  + 3.56658111437e-07 * X_pqq_c(14) + 3.03585208545e-08 * X_glc__D_e(6)
# X_icit_e*(6) =
# X_phe__L_e*(9) =
# X_ser__L_e*(3) =  + 1.85011073287e-07 * X_pqq_c(14) + 4.03681690256e-08 * X_glc__D_e(6)
# X_tyr__L_e*(9) =  + 1.82234760987e-07 * X_pqq_c(14)
#        finishing in 17.738735675811768  s
# Global execution time =  26.569496870040894  s

# %% [markdown]
# # Test of a very large size example (Chlamydomonas reinhardtii from BIGG)

# %%
import time

globalstart = time.time()

start = time.time()
print("Reading the model")
model=cobra.io.read_sbml_model('NA_Offline/iRC1080.xml')
end = time.time()
print("       finishing in",end - start," s")

start = time.time()
print("Scaling the model")
RescaleModel(model,0.5)
Model_Missing_Formula(model)

end = time.time()
print("       finishing in",end - start," s")

start = time.time()
print("Performing a FBA")
fba = model.optimize()
end = time.time()
print("       finishing in",end - start," s")
V=fba.x_dict

start = time.time()
print("Pick a sample flux vector")
VD=cobra.flux_analysis.sample(model,1).to_dict()
V=dict()
for r in VD:
    V[r]=VD[r].get(0)
end = time.time()
print("       finishing in",end - start," s")

    
start = time.time()
print("AIO Computation")
PrintRepartition(model,V)
end = time.time()
print("       finishing in",end - start," s")

globalend = time.time()
print("Global execution time = ",globalend - globalstart," s")
# Out:
# Reading the model
#        finishing in 1.7608318328857422  s
# Scaling the model
#        finishing in 11.39441704750061  s
# Performing a FBA
#        finishing in 0.10392904281616211  s
# Pick a sample flux vector
#        finishing in 30.509296894073486  s
# AIO Computation
# ... Creating the metabolite lists
# ... Creating matrix D
# ... Inverting matrix D
# X_mg2_e*(0) =
# X_na1_e*(0) =
# X_nh4_e*(0) =
# X_o2_e*(0) =
# X_photonVis_e*(0) =
# X_pi_e*(0) =
# X_so4_e*(0) =
# X_starch300_h*(0) =
# X_10fthf_c*(20) =
# X_10fthf_h*(20) =
# X_10fthf_m*(20) =
# X_10fthf_x*(20) =
# X_10fthfglu__L_c*(25) =
# X_10fthfglu__L_m*(25) =
# X_12dgr160_h*(35) =
# X_12dgr16018111Z_c*(37) =
# X_12dgr1601819Z_c*(37) =
# X_12dgr1601819Z_h*(37) =
# X_12dgr1801819Z_c*(39) =
# X_12dgr1801819Z_h*(39) =
# X_12dgr18111Z160_h*(0) =
# X_12dgr18111Z18111Z_c*(39) =
# X_12dgr18111Z1819Z_c*(39) =
# X_12dgr18111Z1819Z_h*(39) =
# X_12dgr1819Z160_h*(0) =
# X_12dgr1819Z1619Z_h*(0) =
# X_12dgr1819Z18111Z_c*(39) =
# X_12dgr1819Z18111Z_h*(39) =
# X_12dgr1819Z1819Z_c*(39) =
# X_12dgr1819Z1819Z_h*(39) =
# X_dhmtp_c*(6) =
# X_13dampp_h*(3) =
# X_13dpg_c*(3) =
# X_13dpg_f*(3) =
# X_13dpg_h*(3) =
# X_13dpg_m*(3) =
# X_13oocdcy1829Z11Ea_c*(18) =
# X_13Shocdcy1829Z11Ea_c*(18) =
# X_13Shpocdcy1829Z11Ea_c*(18) =
# X_1acpc_c*(4) =
# X_1acpc_h*(4) =
# X_1acpc_m*(4) =
# X_1agpe180_c*(23) =
# X_1agpe18111Z_c*(23) =
# X_1agpe1819Z_c*(23) =
# X_1agpe1829Z12Z_c*(23) =
# X_1btol_c*(4) =
# X_1Dgali_c*(12) =
# X_1Dgali_h*(12) =
# X_1hdecg3p_c*(19) =
# X_1hdecg3p_h*(19) =
# X_1odec11eg3p_c*(21) =
# X_1odec11eg3p_h*(21) =
# X_1odec9eg3p_c*(21) =
# X_1odec9eg3p_h*(21) =
# X_1odecg3p_c*(21) =
# X_1odecg3p_h*(21) =
# X_1pyr5c_c*(5) =
# X_1pyr5c_m*(5) =
# X_23dhdp_c*(7) =
# X_23dhmb_c*(5) =
# X_23dhmb_h*(5) =
# X_23dhmb_m*(5) =
# X_23dhmp_c*(6) =
# X_23dhmp_h*(6) =
# X_25aics_c*(13) =
# X_25aics_h*(13) =
# X_25dhpp_h*(9) =
# X_25hvitd3_c*(27) =
# X_26dap_LL_c*(7) =
# X_26dap__M_c*(7) =
# X_26dmani_e*(8) =
# X_2ahbut_h*(6) =
# X_2ahethmpp_h*(14) =
# X_2ahethmpp_m*(14) =
# X_2ahhmd_c*(7) =
# X_2ahhmp_c*(7) =
# X_2aobut_x*(4) =
# X_2cpr5p_h*(12) =
# X_2dda7p_h*(7) =
# X_2dhp_c*(6) =
# X_2dhp_m*(6) =
# X_2dhp_n*(6) =
# X_2dr5p_c*(5) =
# X_2h34hppr_c*(9) =
# X_hkmpp_c*(6) =
# X_2h3oppan_m*(3) =
# X_2ippm_c*(7) =
# X_2kmb_c*(5) =
# X_2maacoa_m*(26) =
# X_2mb2coa_m*(26) =
# X_2mbcoa_m*(26) =
# X_2mbdhl_m*(13) =
# X_2me4p_h*(5) =
# X_2mecdp_h*(5) =
# X_2mhob_m*(17) =
# X_2mhop_m*(16) =
# X_2mp2coa_m*(25) =
# X_2mpdhl_m*(12) =
# X_2obut_h*(4) =
# X_2obut_m*(4) =
# X_2pg_c*(3) =
# X_2pg_f*(3) =
# X_2pg_h*(3) =
# X_2pg_m*(3) =
# X_2pglyc_c*(2) =
# X_2pglyc_h*(2) =
# X_2pglyc_x*(2) =
# X_34hpp_c*(9) =
# X_34hpp_h*(9) =
# X_34hpp_m*(9) =
# X_35cgmp_c*(10) =
# X_35cgmp_n*(10) =
# X_3c2hmp_c*(7) =
# X_3c3hmp_c*(7) =
# X_3c3hmp_h*(7) =
# X_3c4mop_c*(7) =
# X_3dhq_h*(7) =
# X_3dhsk_h*(7) =
# X_3dsphgn_c*(18) =
# X_3hbcoa_c*(25) =
# X_3hbcoa_m*(25) =
# X_3hbcoa_x*(25) =
# X_3hbcoa__R_c*(25) =
# X_3hbutACP_h*(0) =
# X_3hcvac11eACP_h*(0) =
# X_3hdcoa_m*(31) =
# X_3hdcoa_x*(31) =
# X_3hddcoa_m*(33) =
# X_3hddcoa_x*(33) =
# X_3hddecACP_h*(0) =
# X_3hdecACP_h*(0) =
# X_3hhcoa_m*(27) =
# X_3hhcoa_x*(27) =
# X_3hhdcoa_m*(37) =
# X_3hhdcoa_x*(37) =
# X_3hhexACP_h*(0) =
# X_3hib_m*(4) =
# X_3hibutcoa_m*(25) =
# X_3hivcoa_m*(26) =
# X_3hlido_c*(14) =
# X_3hmbcoa_m*(26) =
# X_3hmoa_h*(5) =
# X_3hmop_h*(6) =
# X_3hmrsACP_h*(0) =
# X_3hocoa_m*(29) =
# X_3hocoa_x*(29) =
# X_3hoctaACP_h*(0) =
# X_3hoctACP_h*(0) =
# X_3hodcoa_c*(39) =
# X_3hpalmACP_h*(0) =
# X_3hpcoa_c*(24) =
# X_3hpcoa_m*(24) =
# X_3hpp_c*(3) =
# X_3htdcoa_m*(35) =
# X_3htdcoa_x*(35) =
# X_3ig3p_h*(11) =
# X_3mb2coa_m*(26) =
# X_3mbdhl_m*(13) =
# X_3mgcoa_m*(27) =
# X_3mhtpp_m*(17) =
# X_3mob_c*(5) =
# X_3mob_h*(5) =
# X_3mob_m*(5) =
# X_3mop_c*(6) =
# X_3mop_h*(6) =
# X_3mop_m*(6) =
# X_mtpp_c*(4) =
# X_3ocvac11eACP_h*(0) =
# X_3odcoa_m*(31) =
# X_3odcoa_x*(31) =
# X_3oddcoa_m*(33) =
# X_3oddcoa_x*(33) =
# X_3oddecACP_h*(0) =
# X_3odecACP_h*(0) =
# X_3ohcoa_m*(27) =
# X_3ohcoa_x*(27) =
# X_3ohdcoa_m*(37) =
# X_3ohdcoa_x*(37) =
# X_3ohexACP_h*(0) =
# X_3omrsACP_h*(0) =
# X_3oocoa_m*(29) =
# X_3oocoa_x*(29) =
# X_3ooctACP_h*(0) =
# X_3ooctdACP_h*(0) =
# X_3ohodcoa_c*(39) =
# X_3opalmACP_h*(0) =
# X_3opcoa_c*(24) =
# X_3otdcoa_m*(35) =
# X_3otdcoa_x*(35) =
# X_3pg_c*(3) =
# X_3pg_f*(3) =
# X_3pg_h*(3) =
# X_3pg_m*(3) =
# X_3pg_x*(3) =
# X_3php_h*(3) =
# X_3psme_h*(10) =
# X_3sala_h*(3) =
# X_3sala_m*(3) =
# X_3snpyr_h*(3) =
# X_3snpyr_m*(3) =
# X_3spyr_h*(3) =
# X_3spyr_m*(3) =
# X_44mctr_c*(29) =
# X_44mzym_c*(29) =
# X_4abut_c*(4) =
# X_4abut_h*(4) =
# X_4abut_m*(4) =
# X_4abutn_h*(4) =
# X_4abutn_m*(4) =
# X_4abz_c*(7) =
# X_4adcho_c*(10) =
# X_4c2me_h*(14) =
# X_4fumacac_c*(8) =
# X_4fumacac_n*(8) =
# X_4hproara_g*(0) =
# X_4hproaraara_g*(0) =
# X_4hproaraaraara_g*(0) =
# X_4hproaraaraaragal_g*(0) =
# X_4hproaraaragal_g*(0) =
# X_4hproaraaragalara_g*(0) =
# X_4hproaraaragalmeara_g*(0) =
# X_4hproaraara_ara_gal_g*(0) =
# X_4hproaraara_gal_gal_g*(0) =
# X_4hproaraara_gal_megal_g*(0) =
# X_4hproaraaramegal_g*(0) =
# X_4hproaragal_g*(0) =
# X_4hproara_aragalara_gal_g*(0) =
# X_4hproara_aragal_gal_g*(0) =
# X_4hproara_aragal_galara_g*(0) =
# X_4hproara_ara_gal_g*(0) =
# X_4hproara_ara_galara_g*(0) =
# X_4hproara_ara_galaragal_g*(0) =
# X_4hprogal_g*(0) =
# X_4hpro_LT_c*(5) =
# X_4hpro_LT_g*(5) =
# X_4izp_c*(6) =
# X_4mlacac_c*(8) =
# X_4mlacac_n*(8) =
# X_4mop_c*(6) =
# X_4mop_h*(6) =
# X_4mop_m*(6) =
# X_4mzym_c*(28) =
# X_4mzym_int1_c*(29) =
# X_4mzym_int2_c*(28) =
# X_4ogm_c*(5) =
# X_4pasp_h*(4) =
# X_ptcys_c*(12) =
# X_4ppan_c*(9) =
# X_4ppcys_c*(12) =
# X_4pyrdx_c*(8) =
# X_4r5au_h*(9) =
# X_56dh5flura_c*(4) =
# X_56dura_c*(4) =
# X_5aizc_c*(9) =
# X_5aizc_h*(9) =
# X_5aop_h*(5) =
# X_5aprbu_h*(9) =
# X_5apru_h*(9) =
# X_5flura_c*(4) =
# X_5flura_e*(4) =
# X_5flurimp_c*(9) =
# X_5forthf_c*(20) =
# X_5fthf_c*(20) =
# X_5fthf_e*(20) =
# X_5fthf_m*(20) =
# X_5hiu_m*(5) =
# X_5houdic_m*(5) =
# X_5mdr1p_c*(6) =
# X_5mdru1p_c*(6) =
# X_5mta_c*(11) =
# X_5mta_h*(11) =
# X_5mta_m*(11) =
# X_5mthf_m*(20) =
# X_5mtr_c*(6) =
# X_5prdmbz_c*(14) =
# X_6mpur_c*(5) =
# X_6mpur_e*(5) =
# X_6pgc_c*(6) =
# X_6pgc_h*(6) =
# X_6pgl_c*(6) =
# X_6pgl_h*(6) =
# X_6tgsnmp_c*(10) =
# X_6tins5mp_c*(10) =
# X_6txan5mp_c*(10) =
# X_7dhchsterol_c*(27) =
# X_aacoa_c*(25) =
# X_aacoa_m*(25) =
# X_aacoa_x*(25) =
# X_aact_x*(3) =
# X_ac_c*(2) =
# X_ac_e*(2) =
# X_ac_h*(2) =
# X_ac_m*(2) =
# X_ac_s*(2) =
# X_acac_c*(4) =
# X_acac_m*(4) =
# X_acac_x*(4) =
# X_acACP_h*(0) =
# X_acald_c*(2) =
# X_acald_h*(2) =
# X_acald_m*(2) =
# X_acald_x*(2) =
# X_acaro_h*(40) =
# X_acaro_u*(40) =
# X_accoa_c*(23) =
# X_accoa_h*(23) =
# X_accoa_m*(23) =
# X_accoa_s*(23) =
# X_accoa_x*(23) =
# X_acg5p_c*(7) =
# X_acg5sa_c*(7) =
# X_acg5sa_m*(7) =
# X_acgam1p_c*(8) =
# X_acgam6p_c*(8) =
# X_acglu_c*(7) =
# X_achms_c*(6) =
# X_achms_h*(6) =
# X_acorn_c*(7) =
# X_acorn_m*(7) =
# X_ACP_c*(0) =
# X_ACP_h*(0) =
# X_acser_c*(5) =
# X_acser_h*(5) =
# X_acser_m*(5) =
# X_actACP_h*(0) =
# X_actp_h*(2) =
# X_actp_m*(2) =
# X_ad_c*(2) =
# X_ad_e*(2) =
# X_ade_c*(5) =
# X_ade_e*(5) =
# X_adhlam_h*(10) =
# X_adhlam_m*(10) =
# X_adn_c*(10) =
# X_adn_m*(10) =
# X_adp_c*(10) =
# X_adp_f*(10) =
# X_adp_h*(10) =
# X_adp_m*(10) =
# X_adp_n*(10) =
# X_adpglc_h*(16) =
# X_adprib_c*(15) =
# X_aflbala_c*(3) =
# X_aflburppa_c*(4) =
# X_agm_m*(5) =
# X_agm_n*(5) =
# X_ahcys_c*(14) =
# X_ahcys_g*(14) =
# X_ahcys_h*(14) =
# X_ahcys_m*(14) =
# X_ahcys_n*(14) =
# X_ahdt_c*(9) =
# X_aicar_c*(9) =
# X_aicar_h*(9) =
# X_air_c*(8) =
# X_air_h*(8) =
# X_akg_c*(5) =
# X_akg_h*(5) =
# X_akg_m*(5) =
# X_ala_B_c*(3) =
# X_ala_B_h*(3) =
# X_ala_B_m*(3) =
# X_alac__S_h*(5) =
# X_alac__S_m*(5) =
# X_ala__L_c*(3) =
# X_ala__L_m*(3) =
# X_ala__L_x*(3) =
# X_alatrna_m*(0) =
# X_allphn_c*(2) =
# X_allphn_m*(2) =
# X_alltn_c*(4) =
# X_alltn_e*(4) =
# X_alltn_m*(4) =
# X_alltt_c*(4) =
# X_alltt_e*(4) =
# X_alltt_m*(4) =
# X_alpro_m*(0) =
# X_amet_c*(15) =
# X_amet_g*(15) =
# X_amet_h*(15) =
# X_amet_m*(15) =
# X_amet_n*(15) =
# X_ametam_c*(14) =
# X_ametam_h*(14) =
# X_ametam_m*(14) =
# X_amp_c*(10) =
# X_amp_h*(10) =
# X_amp_m*(10) =
# X_amp_n*(10) =
# X_ans_c*(10) =
# X_anth_h*(7) =
# X_anxan_u*(40) =
# X_ap4a_n*(20) =
# X_apoACP_c*(0) =
# X_apoACP_h*(0) =
# X_apocytc_h*(0) =
# X_apocytc_m*(0) =
# X_apofetn_h*(0) =
# X_apotfen_h*(0) =
# X_apppa_n*(20) =
# X_aps_c*(10) =
# X_aps_h*(10) =
# X_aps_m*(10) =
# X_aps_n*(10) =
# X_arab__L_c*(5) =
# X_arg__L_c*(6) =
# X_arg__L_e*(6) =
# X_arg__L_m*(6) =
# X_argsuc_c*(10) =
# X_argtrna_c*(0) =
# X_arso4_c*(6) =
# X_ascb__L_u*(6) =
# X_asnglcnacglcnacman_man_manman_manman_manmanman_c*(0) =
# X_asnglcnacglcnacman_man_manman_manman_manmanmanglc_c*(0) =
# X_asnglcnacglcnacman_man_manman_manman_manmanmanglcglc_c*(0) =
# X_asnglcnacglcnacman_man_manman_manman_manmanmanglcglcglc_c*(0) =
# X_asnglcnacglcnacman_man_manman_man_man_man_manman_c*(0) =
# X_asnglcnacglcnacman_man_manman_man_manmanman_c*(0) =
# X_asnglcnacglcnacman_man_man_man_man_c*(0) =
# X_asn__L_c*(4) =
# X_asn__L_m*(4) =
# X_asn__L_x*(4) =
# X_asntrna_m*(0) =
# X_Asn_X_Ser_Thr_c*(0) =
# X_asp__L_c*(4) =
# X_asp__L_h*(4) =
# X_asp__L_m*(4) =
# X_asp__L_x*(4) =
# X_aspsa_c*(4) =
# X_aspsa_h*(4) =
# X_asptrna_m*(0) =
# X_asqdca18111Z160_c*(61) =
# X_asqdca1819Z160_c*(61) =
# X_asqdca1829Z12Z160_c*(61) =
# X_asqdca1839Z12Z15Z160_c*(61) =
# X_asqdpa18111Z160_c*(61) =
# X_asqdpa1819Z160_c*(61) =
# X_asqdpa1829Z12Z160_c*(61) =
# X_asqdpa1839Z12Z15Z160_c*(61) =
# X_atp_c*(10) =
# X_atp_f*(10) =
# X_atp_h*(10) =
# X_atp_m*(10) =
# X_atp_n*(10) =
# X_avite1_h*(29) =
# X_b2coa_c*(25) =
# X_b2coa_m*(25) =
# X_b2coa_x*(25) =
# X_bamppald_h*(0) =
# X_B_ara1p_c*(5) =
# X_bathorhodopsin_s*(0) =
# X_bcryptox_u*(40) =
# X_bilirub_h*(33) =
# X_biliverd_h*(33) =
# X_btal_c*(4) =
# X_btal_h*(4) =
# X_btcoa_c*(25) =
# X_btcoa_h*(25) =
# X_btcoa_m*(25) =
# X_btcoa_x*(25) =
# X_btnCCP_h*(0) =
# X_but_c*(4) =
# X_but2eACP_h*(0) =
# X_butACP_h*(388) =
# X_bvite_h*(28) =
# X_ca_c*(18) =
# X_cacoa_c*(39) =
# X_cala_c*(4) =
# X_camp_c*(10) =
# X_camp_n*(10) =
# X_carn_h*(9) =
# X_caro_h*(40) =
# X_caro_u*(40) =
# X_cbasp_c*(5) =
# X_cbasp_m*(5) =
# X_Ncbmpts_m*(5) =
# X_Ncbmpts_n*(5) =
# X_cbp_c*(1) =
# X_cbp_h*(1) =
# X_cbp_m*(1) =
# X_cbtnCCP_h*(0) =
# X_cdp_c*(9) =
# X_cdp_m*(9) =
# X_cdp12dgr18111Z160_c*(46) =
# X_cdp12dgr18111Z160_h*(46) =
# X_cdp12dgr1819Z160_c*(46) =
# X_cdp12dgr1819Z160_h*(46) =
# X_cdpea_c*(11) =
# X_cholphya_h*(55) =
# X_cholphya_u*(55) =
# X_chlaemr_u*(55) =
# X_chlb_u*(55) =
# X_chlld_h*(35) =
# X_chlld_u*(35) =
# X_chldb_h*(35) =
# X_chldb_u*(35) =
# X_chlstol_c*(27) =
# X_chor_c*(10) =
# X_chor_h*(10) =
# X_chsterol_c*(27) =
# X_cit_c*(6) =
# X_cit_m*(6) =
# X_cit_x*(6) =
# X_cital_c*(20) =
# X_cital_e*(20) =
# X_citalald_c*(18) =
# X_citalo_c*(20) =
# X_citalppa_c*(18) =
# X_citr__L_c*(6) =
# X_citr__L_h*(6) =
# X_citr__L_m*(6) =
# X_cmp_c*(9) =
# X_cmp_h*(9) =
# X_co_c*(1) =
# X_co_h*(1) =
# X_co2_c*(1) =
# X_co2_e*(1) =
# X_co2_h*(1) =
# X_co2_m*(1) =
# X_co2_x*(1) =
# X_coa_c*(21) =
# X_coa_h*(21) =
# X_coa_m*(21) =
# X_coa_s*(21) =
# X_coa_x*(21) =
# X_cpp1_h*(0) =
# X_cpp3_h*(0) =
# X_cpppg1_h*(36) =
# X_cpppg3_h*(36) =
# X_crpxan_u*(40) =
# X_csn_c*(4) =
# X_ctp_c*(9) =
# X_ctp_h*(9) =
# X_ctp_m*(9) =
# X_cyart_c*(30) =
# X_cyeuol_c*(30) =
# X_cys__L_c*(3) =
# X_cys__L_h*(3) =
# X_cys__L_m*(3) =
# X_cyst__L_h*(7) =
# X_cystrna_c*(0) =
# X_cytc_h*(0) =
# X_cytc_m*(0) =
# X_cytd_c*(9) =
# X_cytP450o_c*(0) =
# X_cytP450o_h*(0) =
# X_cytP450r_c*(0) =
# X_cytP450r_h*(0) =
# X_dad_2_c*(10) =
# X_dadp_c*(10) =
# X_dadp_h*(10) =
# X_dadp_m*(10) =
# X_damp_c*(10) =
# X_damp_h*(10) =
# X_damp_m*(10) =
# X_datp_c*(10) =
# X_datp_m*(10) =
# X_db4p_h*(4) =
# X_dc2coa_m*(31) =
# X_dc2coa_x*(31) =
# X_dca_h*(10) =
# X_dcaACP_h*(394) =
# X_dcacoa_m*(31) =
# X_dcacoa_x*(31) =
# X_dcamp_c*(14) =
# X_dcamp_h*(14) =
# X_dcaro_h*(40) =
# X_dcdp_c*(9) =
# X_dcdp_m*(9) =
# X_dcmp_c*(9) =
# X_dctp_c*(9) =
# X_dctp_m*(9) =
# X_dcyt_c*(9) =
# X_dd2coa_m*(33) =
# X_dd2coa_x*(33) =
# X_ddca_h*(12) =
# X_ddcaACP_h*(0) =
# X_ddcacoa_m*(33) =
# X_ddcacoa_x*(33) =
# X_ddmcital_c*(18) =
# X_ddsmsterol_c*(27) =
# X_dedoldp_c*(55) =
# X_degly_e*(6) =
# X_dgdg1819Z160_h*(0) =
# X_dgdg1819Z1617Z_h*(0) =
# X_dgdg1819Z1619Z_h*(0) =
# X_dgdg1819Z1627Z10Z_h*(0) =
# X_dgdg1819Z1634Z7Z10Z_h*(0) =
# X_dgdg1819Z1637Z10Z13Z_h*(0) =
# X_dgdg1829Z12Z160_h*(0) =
# X_dgdg1829Z12Z1617Z_h*(0) =
# X_dgdg1829Z12Z1619Z_h*(0) =
# X_dgdg1829Z12Z1627Z10Z_h*(0) =
# X_dgdg1829Z12Z1634Z7Z10Z_h*(0) =
# X_dgdg1829Z12Z1637Z10Z13Z_h*(0) =
# X_dgdg1839Z12Z15Z160_h*(0) =
# X_dgdg1839Z12Z15Z1627Z10Z_h*(0) =
# X_dgdg1839Z12Z15Z1634Z7Z10Z_h*(0) =
# X_dgdg1839Z12Z15Z1637Z10Z13Z_h*(0) =
# X_dgdg1839Z12Z15Z1644Z7Z10Z13Z_h*(0) =
# X_dgdp_c*(10) =
# X_dgdp_m*(10) =
# X_dghs16018111Z_c*(41) =
# X_dghs1601819Z_c*(41) =
# X_dghs18111Z18111Z_c*(43) =
# X_dghs18111Z1819Z_c*(43) =
# X_dghs1819Z18111Z_c*(43) =
# X_dghs1819Z1819Z_c*(43) =
# X_dgmp_c*(10) =
# X_dgsn_c*(10) =
# X_dgtp_c*(10) =
# X_dgtp_m*(10) =
# X_dgts16018111Z_c*(44) =
# X_dgts1601819Z_c*(44) =
# X_dgts1601829Z12Z_c*(44) =
# X_dgts1601835Z9Z12Z_c*(44) =
# X_dgts1601845Z9Z12Z15Z_c*(44) =
# X_dgts18111Z18111Z_c*(46) =
# X_dgts18111Z1819Z_c*(46) =
# X_dgts18111Z1829Z12Z_c*(46) =
# X_dgts18111Z1835Z9Z12Z_c*(46) =
# X_dgts18111Z1845Z9Z12Z15Z_c*(46) =
# X_dgts1819Z18111Z_c*(46) =
# X_dgts1819Z1819Z_c*(46) =
# X_dgts1819Z1829Z12Z_c*(46) =
# X_dgts1819Z1835Z9Z12Z_c*(46) =
# X_dgts1819Z1845Z9Z12Z15Z_c*(46) =
# X_dgts1829Z12Z18111Z_c*(46) =
# X_dgts1829Z12Z1819Z_c*(46) =
# X_dgts1829Z12Z1829Z12Z_c*(46) =
# X_dgts1829Z12Z1835Z9Z12Z_c*(46) =
# X_dgts1829Z12Z1845Z9Z12Z15Z_c*(46) =
# X_dgts1839Z12Z15Z18111Z_c*(46) =
# X_dgts1839Z12Z15Z1819Z_c*(46) =
# X_dgts1839Z12Z15Z1835Z9Z12Z_c*(46) =
# X_dgts1839Z12Z15Z1845Z9Z12Z15Z_c*(46) =
# X_dhap_c*(3) =
# X_dhap_f*(3) =
# X_dhap_h*(3) =
# X_dhap_m*(3) =
# X_dhdascb_u*(6) =
# X_dhf_c*(19) =
# X_dhlam_h*(8) =
# X_dhlam_m*(8) =
# X_dhlpro_m*(0) =
# X_dhnpt_c*(9) =
# X_dhor__S_c*(5) =
# X_dhor__S_m*(5) =
# X_dhpmp_c*(9) =
# X_dhpt_c*(14) =
# X_dhretinol_s*(20) =
# X_din_c*(10) =
# X_dkmpp_c*(6) =
# X_dma_c*(2) =
# X_dmbzid_c*(9) =
# X_dmcital_c*(19) =
# X_dmlz_h*(13) =
# X_dmpp_c*(5) =
# X_dmpp_h*(5) =
# X_23dmphol_h*(28) =
# X_dna5mtc_n*(0) =
# X_dnac_n*(0) =
# X_dnad_c*(21) =
# X_dnad_h*(21) =
# X_dnad_n*(21) =
# X_doldp_c*(55) =
# X_doldpglcnac_c*(63) =
# X_doldpglcnacglcnac_c*(71) =
# X_doldpglcnacglcnacman_c*(77) =
# X_doldpglcnacglcnacman_man_manman_manman_manmanman_c*(125) =
# X_doldpglcnacglcnacman_man_manman_manman_manmanmanglc_c*(131) =
# X_doldpglcnacglcnacman_man_manman_manman_manmanmanglcglc_c*(137) =
# X_doldpglcnacglcnacman_man_manman_manman_manmanmanglcglcglc_c*(143) =
# X_doldpglcnacglcnacman_man_man_manman_manmanman_c*(119) =
# X_doldpglcnacglcnacman_manmanman_manmanman_c*(113) =
# X_doldpglcnacglcnacman_manman_manmanman_c*(107) =
# X_doldpglcnacglcnacman_man_man_c*(89) =
# X_doldpglcnacglcnacman_man_manman_c*(95) =
# X_doldpglcnacglcnacman_man_manmanman_c*(101) =
# X_doldpglcnacglcnacmanman_c*(83) =
# X_dolmanp_c*(61) =
# X_dolp_c*(55) =
# X_dolpglc_c*(61) =
# X_dpcoa_c*(21) =
# X_drib_c*(5) =
# X_dscl_h*(42) =
# X_dsmsterol_c*(27) =
# X_dtdp_c*(10) =
# X_dtdp_m*(10) =
# X_dtmp_c*(10) =
# X_dttp_c*(10) =
# X_dttp_m*(10) =
# X_dudp_c*(9) =
# X_dudp_m*(9) =
# X_dump_c*(9) =
# X_duri_c*(9) =
# X_dutp_c*(9) =
# X_dutp_m*(9) =
# X_dvchlda_h*(35) =
# X_dtocophe_h*(27) =
# X_dvpchlda_h*(35) =
# X_dxyl5p_h*(5) =
# X_e4p_h*(4) =
# X_ecaro_h*(40) =
# X_echin_u*(40) =
# X_egly_e*(4) =
# X_eig3p_c*(6) =
# X_eig3p_h*(6) =
# X_epm_h*(12) =
# X_etfox_m*(0) =
# X_etfrd_m*(0) =
# X_etha_c*(2) =
# X_ethamp_c*(2) =
# X_etoh_c*(2) =
# X_etoh_h*(2) =
# X_etoh_m*(2) =
# X_etoh_x*(2) =
# X_f1p_h*(6) =
# X_f26bp_c*(6) =
# X_f2p_h*(6) =
# X_f6p_B_c*(6) =
# X_f6p_B_h*(6) =
# X_fad_c*(27) =
# X_fad_h*(27) =
# X_fad_m*(27) =
# X_fad_x*(27) =
# X_fadh2_c*(27) =
# X_fadh2_h*(27) =
# X_fadh2_m*(27) =
# X_fadh2_x*(27) =
# X_fald_c*(1) =
# X_fdp_B_c*(6) =
# X_fdp_B_f*(6) =
# X_fdp_B_h*(6) =
# X_fdp_B_m*(6) =
# X_fdxox_c*(0) =
# X_fdxox_h*(0) =
# X_fdxox_m*(0) =
# X_fdxox_u*(0) =
# X_fdxrd_c*(0) =
# X_fdxrd_h*(0) =
# X_fdxrd_m*(0) =
# X_fdxrd_u*(0) =
# X_fe2_c*(0) =
# X_fe2_e*(0) =
# X_fe2_h*(0) =
# X_fe3_c*(0) =
# X_fe3_e*(0) =
# X_fe3_h*(0) =
# X_fgam_c*(8) =
# X_fgam_h*(8) =
# X_fgam_m*(8) =
# X_ficytb5_c*(0) =
# X_ficytc_h*(0) =
# X_ficytc_m*(0) =
# X_ficytc_x*(0) =
# X_fmettrna_c*(0) =
# X_fmn_c*(17) =
# X_focytb5_c*(0) =
# X_focytc_h*(0) =
# X_focytc_m*(0) =
# X_focytc_x*(0) =
# X_fol_c*(19) =
# X_for_c*(1) =
# X_for_h*(1) =
# X_for_m*(1) =
# X_for_x*(1) =
# X_fpram_c*(8) =
# X_fpram_h*(8) =
# X_fprica_c*(10) =
# X_frdp_c*(15) =
# X_frdp_h*(15) =
# X_frdp_m*(15) =
# X_frmd_c*(1) =
# X_frmd_x*(1) =
# X_fru_B_c*(6) =
# X_fru_B_h*(6) =
# X_fum_c*(4) =
# X_fum_h*(4) =
# X_fum_m*(4) =
# X_g1p_c*(6) =
# X_g1p_h*(6) =
# X_g3p_c*(3) =
# X_g3p_f*(3) =
# X_g3p_h*(3) =
# X_g3p_m*(3) =
# X_g3pe_c*(5) =
# X_g6p_A_c*(6) =
# X_g6p_A_h*(6) =
# X_g6p_A_n*(6) =
# X_g6p_B_c*(6) =
# X_g6p_B_h*(6) =
# X_gal_c*(6) =
# X_gal_h*(6) =
# X_gal_n*(6) =
# X_gal1p_c*(6) =
# X_gal1p_h*(6) =
# X_galctn__D_n*(6) =
# X_gam6p_c*(6) =
# X_gar_c*(7) =
# X_gar_h*(7) =
# X_gar_m*(7) =
# X_gcald_c*(2) =
# X_gcarote_h*(40) =
# X_gcarote_u*(40) =
# X_gdp_c*(10) =
# X_gdp_h*(10) =
# X_gdp_m*(10) =
# X_gdpmann_c*(16) =
# X_gdptp_c*(10) =
# X_ggchlda_u*(55) =
# X_ggchldb_u*(0) =
# X_ggdp_h*(20) =
# X_ggdp_u*(20) =
# X_ggl_h*(9) =
# X_Glc_aD_c*(6) =
# X_Glc_aD_h*(6) =
# X_glc__bD_c*(6) =
# X_glc__bD_h*(6) =
# X_glcn_h*(6) =
# X_glcur_c*(6) =
# X_gln__L_c*(5) =
# X_gln__L_e*(5) =
# X_gln__L_h*(5) =
# X_gln__L_m*(5) =
# X_glntrna_c*(0) =
# X_glu1sa_h*(5) =
# X_glu5p_c*(5) =
# X_glu5p_m*(5) =
# X_glu5p_x*(5) =
# X_glu5sa_c*(5) =
# X_glu5sa_x*(5) =
# X_glucys_h*(8) =
# X_glu__L_c*(5) =
# X_glu__L_h*(5) =
# X_glu__L_m*(5) =
# X_glutrna_c*(0) =
# X_glutrna_h*(0) =
# X_glx_c*(2) =
# X_glx_h*(2) =
# X_glx_m*(2) =
# X_glx_x*(2) =
# X_gly_c*(2) =
# X_gly_h*(2) =
# X_gly_m*(2) =
# X_gly_x*(2) =
# X_glyald_c*(3) =
# X_glyald_h*(3) =
# X_glyc_c*(3) =
# X_glyc_h*(3) =
# X_glyc3p_c*(3) =
# X_glyc3p_h*(3) =
# X_glyclt_c*(2) =
# X_glyclt_h*(2) =
# X_glyclt_m*(2) =
# X_glyclt_x*(2) =
# X_glyc__R_c*(3) =
# X_glyc__R_h*(3) =
# X_glyc__R_m*(3) =
# X_glytrna_c*(0) =
# X_glytrna_m*(0) =
# X_gmp_c*(10) =
# X_gmp_m*(10) =
# X_gmp_n*(10) =
# X_grdp_c*(10) =
# X_grdp_h*(10) =
# X_gsn_c*(10) =
# X_gthox_c*(20) =
# X_gthox_h*(20) =
# X_gthox_m*(20) =
# X_gthox_u*(20) =
# X_gthrd_c*(10) =
# X_gthrd_h*(10) =
# X_gthrd_m*(10) =
# X_gthrd_u*(10) =
# X_gtp_c*(10) =
# X_gtp_h*(10) =
# X_gtp_m*(10) =
# X_gtp_n*(10) =
# X_gua_c*(5) =
# X_gua_e*(5) =
# X_h_c*(0) =
# X_h_e*(0) =
# X_h_f*(0) =
# X_h_g*(0) =
# X_h_h*(0) =
# X_h_m*(0) =
# X_h_n*(0) =
# X_h_s*(0) =
# X_h_u*(0) =
# X_h_x*(0) =
# X_h2_c*(0) =
# X_h2_h*(0) =
# X_h2_m*(0) =
# X_h2mb4p_h*(5) =
# X_h2o_c*(0) =
# X_h2o_e*(0) =
# X_h2o_f*(0) =
# X_h2o_h*(0) =
# X_h2o_m*(0) =
# X_h2o_n*(0) =
# X_h2o_s*(0) =
# X_h2o_u*(0) =
# X_h2o_x*(0) =
# X_h2o2_c*(0) =
# X_h2o2_h*(0) =
# X_h2o2_m*(0) =
# X_h2o2_n*(0) =
# X_h2o2_x*(0) =
# X_h2s_h*(0) =
# X_hco3_c*(1) =
# X_hco3_e*(1) =
# X_hco3_h*(1) =
# X_hco3_m*(1) =
# X_hcys__L_c*(4) =
# X_hcys__L_h*(4) =
# X_hcys__L_m*(4) =
# X_hdca_c*(16) =
# X_hdca_h*(16) =
# X_hdca_s*(16) =
# X_hdcea_c*(16) =
# X_hdcea_h*(16) =
# X_hdd2coa_m*(37) =
# X_hdd2coa_x*(37) =
# X_hdeACP_h*(400) =
# X_hemeA_m*(49) =
# X_hemeO_m*(49) =
# X_hexACP_h*(0) =
# X_hgentis_c*(8) =
# X_hgentis_h*(8) =
# X_his__L_c*(6) =
# X_his__L_e*(6) =
# X_his__L_h*(6) =
# X_hisp_c*(6) =
# X_hisp_h*(6) =
# X_hista_c*(5) =
# X_histd_c*(6) =
# X_histd_h*(6) =
# X_histrna_c*(0) =
# X_hmbil_h*(40) =
# X_hmgcoa_c*(27) =
# X_hmgcoa_m*(27) =
# X_hmppp9_h*(35) =
# X_hom__L_h*(4) =
# X_hpglu_m*(29) =
# X_hpyr_c*(3) =
# X_hpyr_m*(3) =
# X_so3_c*(0) =
# X_so3_e*(0) =
# X_so3_h*(0) =
# X_so3_m*(0) =
# X_hx2coa_m*(27) =
# X_hx2coa_x*(27) =
# X_hxan_c*(5) =
# X_hxan_e*(5) =
# X_hxcoa_m*(27) =
# X_hxcoa_x*(27) =
# X_hxdcal_c*(16) =
# X_hxdceal_c*(16) =
# X_ibcoa_m*(25) =
# X_icit_c*(6) =
# X_icit_m*(6) =
# X_icit_x*(6) =
# X_idp_c*(10) =
# X_idp_m*(10) =
# X_ile__L_c*(6) =
# X_ile__L_h*(6) =
# X_ile__L_m*(6) =
# X_iletrna_c*(0) =
# X_im4ac_c*(5) =
# X_im4act_c*(5) =
# X_imacp_c*(6) =
# X_imacp_h*(6) =
# X_imp_c*(10) =
# X_imp_h*(10) =
# X_imp_m*(10) =
# X_indole_h*(8) =
# X_inost_c*(6) =
# X_inost_h*(6) =
# X_ins_c*(10) =
# X_ipdp_c*(5) =
# X_ipdp_h*(5) =
# X_itp_c*(10) =
# X_itp_m*(10) =
# X_ivcoa_m*(26) =
# X_lac__D_c*(3) =
# X_lac__D_e*(3) =
# X_lac__D_m*(3) =
# X_lac__L_h*(3) =
# X_lac__L_m*(3) =
# X_lac__L_x*(3) =
# X_lald__D_c*(3) =
# X_lanost_c*(30) =
# X_lcts_h*(12) =
# X_Lcyst_h*(3) =
# X_Lcyst_m*(3) =
# X_cysi__L_h*(6) =
# X_leu__L_c*(6) =
# X_leu__L_e*(6) =
# X_leu__L_h*(6) =
# X_leu__L_m*(6) =
# X_leutrna_c*(0) =
# X_Lfmkynr_c*(11) =
# X_lgt__S_c*(13) =
# X_lgt__S_m*(13) =
# X_lido_c*(14) =
# X_lido_e*(14) =
# X_Lkynr_c*(10) =
# X_lnlc_c*(18) =
# X_lnlc_h*(18) =
# X_lnlccoa_c*(39) =
# X_lnlnca_c*(18) =
# X_lnlncacoa_c*(39) =
# X_lnlncg_c*(18) =
# X_lnlncgcoa_c*(39) =
# X_loroxan_u*(0) =
# X_lpam_h*(8) =
# X_lpam_m*(8) =
# X_lpro_m*(0) =
# X_lthstrl_c*(27) =
# X_lumirhodopsin_s*(0) =
# X_lut_u*(40) =
# X_lycop_h*(40) =
# X_lys__L_c*(6) =
# X_lys__L_m*(6) =
# X_lystrna_m*(0) =
# X_mag160_c*(19) =
# X_mag180_c*(21) =
# X_mag18111Z_c*(21) =
# X_mag1819Z_c*(21) =
# X_malACP_h*(0) =
# X_malcoa_c*(24) =
# X_malcoa_h*(24) =
# X_mal__L_c*(4) =
# X_mal__L_f*(4) =
# X_mal__L_h*(4) =
# X_mal__L_m*(4) =
# X_mal__L_x*(4) =
# X_man_c*(6) =
# X_man_h*(6) =
# X_man1p_c*(6) =
# X_man6p_c*(6) =
# X_man6p_h*(6) =
# X_meglyxyl_c*(12) =
# X_meglyxyl_e*(12) =
# X_melib_h*(12) =
# X_melt_h*(12) =
# X_menecyart_c*(31) =
# X_mercppyr_h*(3) =
# X_mercppyr_m*(3) =
# X_mergtrol_c*(29) =
# X_metarhodopsin_s*(0) =
# X_methf_c*(20) =
# X_methf_h*(20) =
# X_methf_m*(20) =
# X_methf_x*(20) =
# X_met__L_c*(5) =
# X_met__L_m*(5) =
# X_mettrna_c*(0) =
# X_mfecostrl_c*(29) =
# X_mfor_h*(2) =
# X_mg2_c*(0) =
# X_mg2_h*(0) =
# X_mg2_u*(0) =
# X_mgdg1819Z160_h*(0) =
# X_mgdg1819Z1617Z_h*(0) =
# X_mgdg1819Z1619Z_h*(0) =
# X_mgdg1819Z1627Z10Z_h*(0) =
# X_mgdg1819Z1637Z10Z13Z_h*(0) =
# X_mgdg1819Z1644Z7Z10Z13Z_h*(0) =
# X_mgdg1829Z12Z160_h*(0) =
# X_mgdg1829Z12Z1617Z_h*(0) =
# X_mgdg1829Z12Z1619Z_h*(0) =
# X_mgdg1829Z12Z1627Z10Z_h*(0) =
# X_mgdg1829Z12Z1634Z7Z10Z_h*(0) =
# X_mgdg1829Z12Z1637Z10Z13Z_h*(0) =
# X_mgdg1829Z12Z1644Z7Z10Z13Z_h*(0) =
# X_mgdg1839Z12Z15Z160_h*(0) =
# X_mgdg1839Z12Z15Z1627Z10Z_h*(0) =
# X_mgdg1839Z12Z15Z1634Z7Z10Z_h*(0) =
# X_mgdg1839Z12Z15Z1637Z10Z13Z_h*(0) =
# X_mgdg1839Z12Z15Z1644Z7Z10Z13Z_h*(0) =
# X_mhpglu_m*(30) =
# X_mi12356p_c*(6) =
# X_mi13456p_c*(6) =
# X_mi13456p_n*(6) =
# X_mi1345p_c*(6) =
# X_mi1345p_n*(6) =
# X_mi1346p_c*(6) =
# X_mi134p_c*(6) =
# X_mi134p_n*(6) =
# X_mi1456p_c*(6) =
# X_mi1456p_n*(6) =
# X_mi145p_c*(6) =
# X_mi145p_n*(6) =
# X_mi14p_c*(6) =
# X_mi14p_n*(6) =
# X_mi1p__D_c*(6) =
# X_mi3456p_c*(6) =
# X_mi34p_c*(6) =
# X_mi34p_n*(6) =
# X_mi3p__D_c*(6) =
# X_mi3p__D_n*(6) =
# X_mi4p__D_c*(6) =
# X_minohp_c*(6) =
# X_mlthf_c*(20) =
# X_mlthf_m*(20) =
# X_mm_m*(4) =
# X_mma_c*(1) =
# X_mmtsa_m*(4) =
# X_mnt_h*(18) =
# X_mppp9_h*(34) =
# X_mppp9me_h*(0) =
# X_2m6phol_h*(27) =
# X_msa_m*(3) =
# X_mthgxl_c*(3) =
# X_mthgxl_x*(3) =
# X_myrsACP_h*(398) =
# X_nac_c*(6) =
# X_nad_c*(21) =
# X_nad_f*(21) =
# X_nad_h*(21) =
# X_nad_m*(21) =
# X_nad_n*(21) =
# X_nad_s*(21) =
# X_nad_x*(21) =
# X_nadh_c*(21) =
# X_nadh_f*(21) =
# X_nadh_h*(21) =
# X_nadh_m*(21) =
# X_nadh_s*(21) =
# X_nadh_x*(21) =
# X_nadp_c*(21) =
# X_nadp_f*(21) =
# X_nadp_h*(21) =
# X_nadp_m*(21) =
# X_nadp_n*(21) =
# X_nadp_s*(21) =
# X_nadp_u*(21) =
# X_nadp_x*(21) =
# X_nadph_c*(21) =
# X_nadph_f*(21) =
# X_nadph_h*(21) =
# X_nadph_m*(21) =
# X_nadph_n*(21) =
# X_nadph_s*(21) =
# X_nadph_u*(21) =
# X_nadph_x*(21) =
# X_ncam_c*(6) =
# X_neoxan_u*(40) =
# X_nh4_c*(0) =
# X_nh4_h*(0) =
# X_nh4_m*(0) =
# X_nh4_n*(0) =
# X_nh4_x*(0) =
# X_nicrns_c*(11) =
# X_nicrnt_c*(11) =
# X_nicrnt_n*(11) =
# X_nmn_c*(11) =
# X_nmn_n*(11) =
# X_no_c*(0) =
# X_no2_c*(0) =
# X_no2_e*(0) =
# X_no2_h*(0) =
# X_no3_c*(0) =
# X_no3_e*(0) =
# X_neuspn_h*(40) =
# X_NPmehis_c*(7) =
# X_nwharg_c*(6) =
# X_o2_c*(0) =
# X_o2_h*(0) =
# X_o2_m*(0) =
# X_o2_n*(0) =
# X_o2_u*(0) =
# X_o2_x*(0) =
# X_oaa_c*(4) =
# X_oaa_f*(4) =
# X_oaa_h*(4) =
# X_oaa_m*(4) =
# X_oaa_x*(4) =
# X_obfool_c*(30) =
# X_oc2coa_m*(29) =
# X_oc2coa_x*(29) =
# X_ocACP_h*(0) =
# X_occoa_m*(29) =
# X_occoa_x*(29) =
# X_ocdca_c*(18) =
# X_ocdca_h*(18) =
# X_ocdcaACP_h*(402) =
# X_ocdccoa_c*(39) =
# X_ocdce9a_c*(18) =
# X_ocdce9a_h*(18) =
# X_ocdce9coa_c*(39) =
# X_ocdcea_c*(18) =
# X_ocdcea_h*(18) =
# X_ocdcecoa_c*(39) =
# X_octa_h*(8) =
# X_octe9ACP_h*(0) =
# X_octeACP_h*(402) =
# X_od2coa_c*(39) =
# X_omppp9_h*(35) =
# X_orn_c*(5) =
# X_orn_e*(5) =
# X_orn_h*(5) =
# X_orn_m*(5) =
# X_orot_c*(5) =
# X_orot_m*(5) =
# X_orot5p_c*(10) =
# X_oxa_m*(2) =
# X_pa_c*(18) =
# X_pa160_h*(35) =
# X_pa16018111Z_c*(37) =
# X_pa1601819Z_c*(37) =
# X_pa1601819Z_h*(37) =
# X_pa1801819Z_c*(39) =
# X_pa1801819Z_h*(39) =
# X_pa1801829Z12Z_c*(39) =
# X_pa1801835Z9Z12Z_c*(39) =
# X_pa1801845Z9Z12Z15Z_c*(39) =
# X_pa18111Z160_c*(37) =
# X_pa18111Z160_h*(37) =
# X_pa18111Z18111Z_c*(39) =
# X_pa18111Z1819Z_c*(39) =
# X_pa18111Z1819Z_h*(39) =
# X_pa18111Z1829Z12Z_c*(39) =
# X_pa18111Z1835Z9Z12Z_c*(39) =
# X_pa18111Z1845Z9Z12Z15Z_c*(39) =
# X_pa1819Z160_c*(37) =
# X_pa1819Z160_h*(37) =
# X_pa1819Z1619Z_h*(0) =
# X_pa1819Z18111Z_c*(39) =
# X_pa1819Z18111Z_h*(39) =
# X_pa1819Z1819Z_c*(39) =
# X_pa1819Z1819Z_h*(39) =
# X_pa1819Z1829Z12Z_c*(39) =
# X_pa1819Z1835Z9Z12Z_c*(39) =
# X_pa1819Z1845Z9Z12Z15Z_c*(39) =
# X_pa1829Z12Z1835Z9Z12Z_c*(39) =
# X_pacoa_c*(39) =
# X_pail18111Z160_c*(43) =
# X_pail18111Z160_e*(43) =
# X_pail1819Z160_c*(43) =
# X_pail1819Z160_e*(43) =
# X_palmACP_h*(400) =
# X_pan4p_c*(11) =
# X_pant__R_c*(6) =
# X_pant__R_m*(6) =
# X_pant__R_n*(6) =
# X_pap_c*(10) =
# X_pap_h*(10) =
# X_paps_c*(10) =
# X_paps_h*(10) =
# X_paps_m*(10) =
# X_pcrd_u*(0) =
# X_pcox_u*(0) =
# X_2p4c2me_h*(14) =
# X_pchlda_h*(0) =
# X_phdp_h*(20) =
# X_phdp_u*(20) =
# X_pdx5p_c*(8) =
# X_pe1801819Z_c*(41) =
# X_pe1801819Z_e*(41) =
# X_pe1801829Z12Z_c*(41) =
# X_pe1801829Z12Z_e*(41) =
# X_pe1801835Z9Z12Z_c*(41) =
# X_pe1801835Z9Z12Z_e*(41) =
# X_pe1801845Z9Z12Z15Z_c*(41) =
# X_pe1801845Z9Z12Z15Z_e*(41) =
# X_pe18111Z1819Z_c*(41) =
# X_pe18111Z1819Z_e*(41) =
# X_pe18111Z1829Z12Z_c*(41) =
# X_pe18111Z1829Z12Z_e*(41) =
# X_pe18111Z1835Z9Z12Z_c*(41) =
# X_pe18111Z1835Z9Z12Z_e*(41) =
# X_pe18111Z1845Z9Z12Z15Z_c*(41) =
# X_pe18111Z1845Z9Z12Z15Z_e*(41) =
# X_pe1819Z1819Z_c*(41) =
# X_pe1819Z1819Z_e*(41) =
# X_pe1819Z1829Z12Z_c*(41) =
# X_pe1819Z1829Z12Z_e*(41) =
# X_pe1819Z1835Z9Z12Z_c*(41) =
# X_pe1819Z1835Z9Z12Z_e*(41) =
# X_pe1819Z1845Z9Z12Z15Z_c*(41) =
# X_pe1819Z1845Z9Z12Z15Z_e*(41) =
# X_pe1829Z12Z1835Z9Z12Z_c*(41) =
# X_pe1829Z12Z1835Z9Z12Z_e*(41) =
# X_pep_c*(3) =
# X_pep_f*(3) =
# X_pep_h*(3) =
# X_pep_m*(3) =
# X_pg18111Z160_c*(40) =
# X_pg18111Z160_e*(40) =
# X_pg18111Z160_h*(40) =
# X_pg18111Z1613E_h*(0) =
# X_pg1819Z160_c*(40) =
# X_pg1819Z160_e*(40) =
# X_pg1819Z160_h*(40) =
# X_pg1819Z1613E_h*(0) =
# X_pg1829Z12Z160_h*(0) =
# X_pg1829Z12Z1613E_h*(0) =
# X_pg1839Z12Z15Z160_h*(0) =
# X_pg1839Z12Z15Z1613E_h*(0) =
# X_pgp18111Z160_c*(40) =
# X_pgp18111Z160_e*(40) =
# X_pgp18111Z160_h*(40) =
# X_pgp1819Z160_c*(40) =
# X_pgp1819Z160_e*(40) =
# X_pgp1819Z160_h*(40) =
# X_phe__L_c*(9) =
# X_phe__L_h*(9) =
# X_phe__L_m*(9) =
# X_pheme_c*(34) =
# X_pheme_h*(34) =
# X_pheme_m*(34) =
# X_phenol_c*(6) =
# X_phetrna_m*(0) =
# X_phom_c*(4) =
# X_phom_h*(4) =
# X_phphbda_h*(35) =
# X_phphtna_u*(55) =
# X_phpyr_c*(9) =
# X_phpyr_h*(9) =
# X_phpyr_m*(9) =
# X_phytfl_h*(0) =
# X_phyto_h*(0) =
# X_phytol_h*(20) =
# X_pi_c*(0) =
# X_pi_f*(0) =
# X_pi_h*(0) =
# X_pi_m*(0) =
# X_pi_n*(0) =
# X_pi_x*(0) =
# X_pmtcoa_c*(37) =
# X_pmtcoa_h*(37) =
# X_pmtcoa_m*(37) =
# X_pmtcoa_s*(37) =
# X_pmtcoa_x*(37) =
# X_pnto__R_c*(9) =
# X_pnto__R_m*(9) =
# X_ppa_c*(3) =
# X_ppa_h*(3) =
# X_ppa_m*(3) =
# X_ppad_m*(0) =
# X_ppap_h*(3) =
# X_ppap_m*(3) =
# X_ppbng_h*(10) =
# X_ppcoa_c*(24) =
# X_ppcoa_h*(24) =
# X_ppcoa_m*(24) =
# X_ppcoa_n*(24) =
# X_ppgpp_c*(10) =
# X_pphn_c*(10) =
# X_pphn_h*(10) =
# X_ppi_c*(0) =
# X_ppi_h*(0) =
# X_ppi_m*(0) =
# X_ppi_n*(0) =
# X_ppi_u*(0) =
# X_ppp9_h*(34) =
# X_pppg9_h*(34) =
# X_pq_h*(8) =
# X_pq_u*(8) =
# X_pqh2_h*(8) =
# X_pqh2_u*(8) =
# X_pqqox_x*(0) =
# X_pqqrd_x*(0) =
# X_pram_c*(5) =
# X_pram_h*(5) =
# X_pran_h*(12) =
# X_prbamp_c*(15) =
# X_prbamp_h*(15) =
# X_prbatp_c*(15) =
# X_prbatp_h*(15) =
# X_prfp_c*(15) =
# X_prfp_h*(15) =
# X_prlp_c*(15) =
# X_prlp_h*(15) =
# X_pro__L_c*(5) =
# X_pro__L_m*(5) =
# X_protds_h*(0) =
# X_protdt_h*(0) =
# X_protrna_c*(0) =
# X_prpncoa_c*(24) =
# X_prpncoa_m*(24) =
# X_prpncoa_n*(24) =
# X_prpp_c*(5) =
# X_prpp_h*(5) =
# X_pser__L_h*(3) =
# X_psphings_c*(18) =
# X_psqldp_c*(30) =
# X_ptrc_c*(4) =
# X_ptrc_h*(4) =
# X_ptrc_m*(4) =
# X_ptth_c*(11) =
# X_pyam5p_c*(8) =
# X_pydam_c*(8) =
# X_pydx_c*(8) =
# X_pydx5p_c*(8) =
# X_pydxn_c*(8) =
# X_pyphphbda_h*(33) =
# X_pyr_c*(3) =
# X_pyr_f*(3) =
# X_pyr_h*(3) =
# X_pyr_m*(3) =
# X_pyr_x*(3) =
# X_q8_m*(49) =
# X_q8h2_m*(49) =
# X_r1p_c*(5) =
# X_r1p_h*(5) =
# X_r5p_c*(5) =
# X_r5p_h*(5) =
# X_raffin_c*(18) =
# X_raffin_h*(18) =
# X_rb15bp_h*(5) =
# X_rdmbzi_c*(14) =
# X_retac_s*(22) =
# X_retinal_h*(20) =
# X_retinal_s*(20) =
# X_retinal_11_cis_s*(20) =
# X_retinol_s*(20) =
# X_retinol_cis_11_s*(20) =
# X_retpalm_s*(36) =
# X_retpalm_11_cis_s*(36) =
# X_rhodopsin_s*(0) =
# X_rib__D_c*(5) =
# X_rib__D_e*(5) =
# X_ribflv_c*(17) =
# X_ribflv_h*(17) =
# X_rnam_c*(11) =
# X_ru5p__D_c*(5) =
# X_ru5p__D_h*(5) =
# X_s_e*(0) =
# X_s17bp_h*(7) =
# X_s7p_h*(7) =
# X_sbt__D_h*(6) =
# X_scl_h*(42) =
# X_scys__L_c*(3) =
# X_scys__L_h*(3) =
# X_scys__L_m*(3) =
# X_sdhlam_m*(12) =
# X_seahcys_c*(14) =
# X_sectrna_m*(0) =
# X_selcys_c*(3) =
# X_selcys_h*(3) =
# X_selcys_m*(3) =
# X_selcyst_c*(7) =
# X_selcyst_h*(7) =
# X_selhcys_c*(4) =
# X_selhcys_h*(4) =
# X_seln_c*(0) =
# X_seln_h*(0) =
# X_seln_m*(0) =
# X_selnp_m*(0) =
# X_slnt_c*(0) =
# X_slnt_e*(0) =
# X_slnt_m*(0) =
# X_ser__L_c*(3) =
# X_ser__L_h*(3) =
# X_ser__L_m*(3) =
# X_sertrna_c*(0) =
# X_sertrna_sec_m*(0) =
# X_sheme_h*(42) =
# X_skm_h*(7) =
# X_skm5p_h*(7) =
# X_so4_c*(0) =
# X_so4_m*(0) =
# X_so4_n*(0) =
# X_sph1p_c*(18) =
# X_sphgn_c*(18) =
# X_sphings_c*(18) =
# X_sphs1p_c*(18) =
# X_spmd_c*(7) =
# X_spmd_h*(7) =
# X_spmd_m*(7) =
# X_sprm_h*(10) =
# X_sqdg160_h*(41) =
# X_sqdg18111Z160_c*(43) =
# X_sqdg18111Z160_h*(43) =
# X_sqdg1819Z160_c*(43) =
# X_sqdg1819Z160_h*(43) =
# X_sqdg1829Z12Z160_h*(0) =
# X_sqdg1839Z12Z15Z160_h*(0) =
# X_sql_c*(30) =
# X_Ssq23epx_c*(30) =
# X_stys_h*(24) =
# X_stcoa_c*(39) =
# X_suc6p_c*(12) =
# X_sucald_c*(4) =
# X_succ_c*(4) =
# X_succ_h*(4) =
# X_succ_m*(4) =
# X_succoa_m*(25) =
# X_suchms_c*(8) =
# X_suchms_h*(8) =
# X_sucr_c*(12) =
# X_sucr_h*(12) =
# X_sucsal_h*(4) =
# X_sucsal_m*(4) =
# X_t3c11vaceACP_h*(0) =
# X_tag16018111Z160_c*(53) =
# X_tag16018111Z180_c*(55) =
# X_tag16018111Z18111Z_c*(55) =
# X_tag16018111Z1819Z_c*(55) =
# X_tag16018111Z1835Z9Z12Z_c*(55) =
# X_tag16018111Z1845Z9Z12Z15Z_c*(55) =
# X_tag1601819Z160_c*(53) =
# X_tag1601819Z180_c*(55) =
# X_tag1601819Z18111Z_c*(55) =
# X_tag1601819Z1819Z_c*(55) =
# X_tag1601819Z1835Z9Z12Z_c*(55) =
# X_tag1601819Z1845Z9Z12Z15Z_c*(55) =
# X_tag1801819Z160_c*(55) =
# X_tag1801819Z180_c*(57) =
# X_tag1801819Z18111Z_c*(57) =
# X_tag1801819Z1819Z_c*(57) =
# X_tag1801819Z1835Z9Z12Z_c*(57) =
# X_tag1801819Z1845Z9Z12Z15Z_c*(57) =
# X_tag18111Z18111Z160_c*(55) =
# X_tag18111Z18111Z180_c*(57) =
# X_tag18111Z18111Z18111Z_c*(57) =
# X_tag18111Z18111Z1819Z_c*(57) =
# X_tag18111Z18111Z1835Z9Z12Z_c*(57) =
# X_tag18111Z18111Z1845Z9Z12Z15Z_c*(57) =
# X_tag18111Z1819Z160_c*(55) =
# X_tag18111Z1819Z180_c*(57) =
# X_tag18111Z1819Z18111Z_c*(57) =
# X_tag18111Z1819Z1819Z_c*(57) =
# X_tag18111Z1819Z1835Z9Z12Z_c*(57) =
# X_tag18111Z1819Z1845Z9Z12Z15Z_c*(57) =
# X_tag1819Z18111Z160_c*(55) =
# X_tag1819Z18111Z180_c*(57) =
# X_tag1819Z18111Z18111Z_c*(57) =
# X_tag1819Z18111Z1819Z_c*(57) =
# X_tag1819Z18111Z1835Z9Z12Z_c*(57) =
# X_tag1819Z18111Z1845Z9Z12Z15Z_c*(57) =
# X_tag1819Z1819Z160_c*(55) =
# X_tag1819Z1819Z180_c*(57) =
# X_tag1819Z1819Z18111Z_c*(57) =
# X_tag1819Z1819Z1819Z_c*(57) =
# X_tag1819Z1819Z1835Z9Z12Z_c*(57) =
# X_tag1819Z1819Z1845Z9Z12Z15Z_c*(57) =
# X_td2coa_m*(35) =
# X_td2coa_x*(35) =
# X_tdcoa_m*(35) =
# X_tdcoa_x*(35) =
# X_tddec2eACP_h*(0) =
# X_tdec2eACP_h*(0) =
# X_tega_c*(8) =
# X_tega_e*(8) =
# X_tfenfe2_h*(0) =
# X_tfenfe3_h*(0) =
# X_tgua_c*(5) =
# X_tgua_e*(5) =
# X_thcys_h*(3) =
# X_thdp_c*(7) =
# X_thex2eACP_h*(0) =
# X_thf_c*(19) =
# X_thf_h*(19) =
# X_thf_m*(19) =
# X_thfglu_c*(24) =
# X_thmpp_h*(12) =
# X_thmpp_m*(12) =
# X_thr__L_c*(4) =
# X_thr__L_h*(4) =
# X_thr__L_m*(4) =
# X_thrtrna_c*(0) =
# X_thrtrna_m*(0) =
# X_thymd_c*(10) =
# X_tmrs2eACP_h*(0) =
# X_toct2eACP_h*(0) =
# X_toctd2eACP_h*(0) =
# X_tpalm2eACP_h*(0) =
# X_trdox_c*(0) =
# X_trdox_h*(0) =
# X_trdrd_c*(0) =
# X_trdrd_h*(0) =
# X_tre_c*(12) =
# X_tre6p_c*(12) =
# X_tre6p_n*(12) =
# X_trnaala_m*(0) =
# X_trnaarg_c*(0) =
# X_trnaasn_m*(0) =
# X_trnaasp_m*(0) =
# X_trnacys_c*(0) =
# X_trnagln_c*(0) =
# X_trnaglu_c*(0) =
# X_trnaglu_h*(0) =
# X_trnagly_c*(0) =
# X_trnagly_m*(0) =
# X_trnahis_c*(0) =
# X_trnaile_c*(0) =
# X_trnaleu_c*(0) =
# X_trnalys_m*(0) =
# X_trnamet_c*(0) =
# X_trnaphe_m*(0) =
# X_trnapro_c*(0) =
# X_trnasecys_m*(0) =
# X_trnaser_c*(0) =
# X_trnathr_c*(0) =
# X_trnathr_m*(0) =
# X_trnatrp_c*(0) =
# X_trnatyr_c*(0) =
# X_trnaval_c*(0) =
# X_trnaval_h*(0) =
# X_trp__L_c*(11) =
# X_trp__L_h*(11) =
# X_trptrna_c*(0) =
# X_tsul_c*(0) =
# X_tsul_e*(0) =
# X_tsul_h*(0) =
# X_tsul_m*(0) =
# X_ttc_ggdp_c*(20) =
# X_ttdca_h*(14) =
# X_tyr__L_c*(9) =
# X_tyr__L_h*(9) =
# X_tyr__L_m*(9) =
# X_tyr_Lso4_c*(9) =
# X_tyrtrna_c*(0) =
# X_uacgam_c*(17) =
# X_udp_c*(9) =
# X_udp_g*(9) =
# X_udp_h*(9) =
# X_udp_m*(9) =
# X_udp_n*(9) =
# X_udparab_c*(14) =
# X_udparab_g*(14) =
# X_udpg_c*(15) =
# X_udpg_h*(15) =
# X_udpg_n*(15) =
# X_udpgal_c*(15) =
# X_udpgal_g*(15) =
# X_udpgal_h*(15) =
# X_udpgalur_c*(15) =
# X_udpglcur_c*(15) =
# X_udpsq_h*(15) =
# X_udpxyl_c*(14) =
# X_ump_c*(9) =
# X_ump_h*(9) =
# X_upp1_h*(40) =
# X_upp3_h*(40) =
# X_uppg1_h*(40) =
# X_uppg3_h*(40) =
# X_ura_c*(4) =
# X_urate_c*(5) =
# X_urate_e*(5) =
# X_urate_m*(5) =
# X_urcan_c*(6) =
# X_urea_c*(1) =
# X_urea_e*(1) =
# X_urea_m*(1) =
# X_uri_c*(9) =
# X_utp_c*(9) =
# X_utp_m*(9) =
# X_val__L_c*(5) =
# X_val__L_h*(5) =
# X_val__L_m*(5) =
# X_valtrna_c*(0) =
# X_valtrna_h*(0) =
# X_vioxan_u*(40) =
# X_vitd3_c*(27) =
# X_whddca_h*(12) =
# X_whhdca_h*(16) =
# X_whlnlc_h*(0) =
# X_whodce9a_h*(0) =
# X_whttdca_h*(14) =
# X_xan_c*(5) =
# X_xmp_c*(10) =
# X_xmp_m*(10) =
# X_xtp_c*(10) =
# X_xtsn_c*(10) =
# X_xu5p__D_h*(5) =
# X_gtocophe_h*(28) =
# X_zeax_u*(40) =
# X_zcarote_h*(40) =
# X_zxan_u*(40) =
# X_zymst_c*(27) =
# X_zymstnl_c*(27) =
# X_asnglcnacglcnacman_man_man_c*(0) =
# X_bhb_m*(4) =
# X_bhb_x*(4) =
# X_cat_c*(27) =
# X_etoh_e*(2) =
# X_for_e*(1) =
# X_glu5sa_m*(5) =
# X_glyclt_e*(2) =
# X_h2_e*(0) =
# X_hcarn_c*(10) =
# X_icit_h*(6) =
# X_na1_c*(0) =
# X_na1_h*(0) =
# X_na1_m*(0) =
# X_na1_x*(0) =
# X_no_h*(0) =
# X_o2D_u*(0) =
# X_photon298_c*(0) =
# X_photon437_u*(0) =
# X_photon438_u*(0) =
# X_photon450_h*(0) =
# X_photon490_s*(0) =
# X_photon646_h*(0) =
# X_photon673_u*(0) =
# X_photon680_u*(0) =
# X_succ_e*(4) =
# X_udg_m*(3) =
# X_urdglyc_m*(3) =
#        finishing in 116.28527617454529  s
# Global execution time =  160.05640196800232  s

# %% [markdown]
# # Test on Synechococcus elongatus PCC 7942

# %%
import time

globalstart = time.time()

start = time.time()
print("Reading the model")
model=cobra.io.read_sbml_model('NA_Offline/iJB785.xml')
end = time.time()
print("       finishing in",end - start," s")

start = time.time()
print("Scaling the model")
RescaleModel(model,0.5)
Model_Missing_Formula(model)

end = time.time()
print("       finishing in",end - start," s")

start = time.time()
print("Performing a FBA")
fba = model.optimize()
end = time.time()
print("       finishing in",end - start," s")
V=fba.x_dict

start = time.time()
print("Pick a sample flux vector")
VD=cobra.flux_analysis.sample(model,1).to_dict()
V=dict()
for r in VD:
    V[r]=VD[r].get(0)
end = time.time()
print("       finishing in",end - start," s")

    
start = time.time()
print("AIO Computation")
res=PrintRepartition(model,V)
end = time.time()
print("       finishing in",end - start," s")

globalend = time.time()
print("Global execution time = ",globalend - globalstart," s")
# Out:
# Reading the model
#        finishing in 0.6645472049713135  s
# Scaling the model
#        finishing in 1.0451128482818604  s
# Performing a FBA
#        finishing in 0.015257835388183594  s
# Pick a sample flux vector
#        finishing in 3.9713032245635986  s
# AIO Computation
# ... Creating the metabolite lists
# ... Creating matrix D
# ... Inverting matrix D
# X_amylose_c*(0) =
# X_so4_e*(0) =
# X_no3_e*(0) =
# X_pi_e*(0) =
# X_photon410_e*(0) =
# X_photon430_e*(0) =
# X_photon450_e*(0) =
# X_photon470_e*(0) =
# X_photon490_e*(0) =
# X_photon510_e*(0) =
# X_photon530_e*(0) =
# X_photon550_e*(0) =
# X_photon570_e*(0) =
# X_photon590_e*(0) =
# X_photon610_e*(0) =
# X_photon630_e*(0) =
# X_photon650_e*(0) =
# X_photon670_e*(0) =
# X_photon690_e*(0) =
# X_leu__L_e*(6) =  + 1.0 * X_leu__L_e(6)
# X_gam6p_c*(6) =  + 0.0684136467447 * X_leu__L_e(6)
# X_cgly_c*(5) =  + 0.0512234056556 * X_leu__L_e(6)
# X_achms_c*(6) =
# X_pcox_u*(0) =
# X_octe9ACP_c*(0) =
# X_fdp_c*(6) =  + 0.0039110410625 * X_leu__L_e(6)
# X_agm_c*(5) =
# X_5caiz_c*(9) =  + 2.60115915141e-05 * X_leu__L_e(6)
# X_pep_c*(3) =  + 0.0137471676356 * X_leu__L_e(6)
# X_coa_c*(21) =  + 0.0465831137566 * X_leu__L_e(6)
# X_hgbam_c*(45) =
# X_nac_c*(6) =
# X_r3mmal_c*(5) =  + 1.02683281208e-05 * X_leu__L_e(6)
# X_leu__L_c*(6) =  + 0.375029167635 * X_leu__L_e(6)
# X_ahcys_c*(14) =
# X_ru5p__D_c*(5) =  + 0.0253114062067 * X_leu__L_e(6)
# X_14dhncoa_c*(32) =
# X_h2o_cx*(0) =
# X_h2s_c*(0) =
# X_orot_c*(5) =  + 4.53607657766e-06 * X_leu__L_e(6)
# X_g1p_c*(6) =
# X_3hdecACP_c*(0) =
# X_na1_c*(0) =
# X_2pglyc_c*(2) =
# X_ala_B_c*(3) =
# X_glyc3p_c*(3) =
# X_pqh2_um*(53) =  + 4.80514667346 * X_leu__L_e(6)
# X_26dap_LL_c*(7) =
# X_ddcaACP_c*(0) =
# X_2pglyc_cx*(2) =
# X_trdox_c*(0) =
# X_3oddecACP_c*(0) =
# X_glu__D_c*(5) =
# X_h_cx*(0) =
# X_dutp_c*(9) =
# X_paps_c*(10) =  + 0.0105959008348 * X_leu__L_e(6)
# X_mg2_c*(0) =
# X_hdeACP_c*(0) =
# X_o2_c*(0) =
# X_anth_c*(7) =
# X_dhpt_c*(14) =
# X_thex2eACP_c*(0) =
# X_fmn_c*(17) =
# X_pppi_c*(0) =
# X_udp_c*(9) =  + 0.170766065056 * X_leu__L_e(6)
# X_cit_c*(6) =  + 5.05550861579e-05 * X_leu__L_e(6)
# X_acACP_c*(0) =
# X_uama_c*(23) =  + 0.0133456332259 * X_leu__L_e(6)
# X_eig3p_c*(6) =
# X_3c4mop_c*(7) =  + 8.43603898954e-07 * X_leu__L_e(6)
# X_lys__L_c*(6) =  + 1.31078828673e-05 * X_leu__L_e(6)
# X_13dpg_c*(3) =  + 0.476010047316 * X_leu__L_e(6)
# X_gmp_c*(10) =  + 0.0476712315018 * X_leu__L_e(6)
# X_utp_c*(9) =  + 0.27536781471 * X_leu__L_e(6)
# X_trdrd_c*(0) =
# X_so4_c*(0) =
# X_5apru_c*(9) =
# X_hmppp9_c*(35) =
# X_pydx5p_c*(8) =
# X_2dhp_c*(6) =
# X_ade_c*(5) =
# X_asp__L_c*(4) =
# X_2sephchc_c*(14) =
# X_acg5p_c*(7) =  + 2.89506576737e-05 * X_leu__L_e(6)
# X_gdp_c*(10) =  + 0.546846179823 * X_leu__L_e(6)
# X_hgbyr_c*(45) =
# X_palmACP_c*(0) =
# X_pser__L_c*(3) =  + 0.018822705137 * X_leu__L_e(6)
# X_ocACP_c*(0) =
# X_dttp_c*(10) =
# X_suc6p_c*(12) =  + 0.0776129612281 * X_leu__L_e(6)
# X_6pgc_c*(6) =  + 0.0248203836084 * X_leu__L_e(6)
# X_gcald_c*(2) =
# X_2p4c2me_c*(14) =  + 2.61577016407e-05 * X_leu__L_e(6)
# X_cmp_c*(9) =  + 1.68156653404e-05 * X_leu__L_e(6)
# X_bm_pro_c*(1) =  + 8.04010408301e-06 * X_leu__L_e(6)
# X_pi_c*(0) =
# X_pnto__R_c*(9) =
# X_dump_c*(9) =
# X_omppp9_c*(35) =
# X_23dhmp_c*(6) =  + 1.41933424509e-05 * X_leu__L_e(6)
# X_gtp_c*(10) =  + 0.546883468751 * X_leu__L_e(6)
# X_4h2oglt_c*(5) =
# X_prfp_c*(15) =
# X_man1p_c*(6) =  + 1.18305769739e-05 * X_leu__L_e(6)
# X_dxyl5p_c*(5) =  + 4.09105733848e-06 * X_leu__L_e(6)
# X_3hddecACP_c*(0) =
# X_cu2_c*(0) =
# X_malACP_c*(0) =
# X_2mahmp_c*(6) =
# X_5g2oxpt_c*(6) =
# X_phpyr_c*(9) =  + 1.99072343011e-05 * X_leu__L_e(6)
# X_fe2_c*(0) =
# X_phllqne_c*(31) =
# X_toct2eACP_c*(0) =
# X_dgdp_c*(10) =
# X_uaccg_c*(20) =  + 0.0635876682352 * X_leu__L_e(6)
# X_acald_c*(2) =
# X_o2s_c*(0) =
# X_phytfl_c*(40) =
# X_alac__S_c*(5) =  + 7.04514518459e-06 * X_leu__L_e(6)
# X_3hmop_c*(6) =  + 9.87661472292e-06 * X_leu__L_e(6)
# X_4abz_c*(7) =
# X_prbamp_c*(15) =
# X_ca2_c*(0) =
# X_glyclt_c*(2) =
# X_butACP_c*(0) =
# X_4ppcys_c*(12) =
# X_udpgal_c*(15) =
# X_f6p_c*(6) =  + 0.127434936402 * X_leu__L_e(6)
# X_his__L_c*(6) =
# X_agdpcbi_c*(68) =
# X_s17bp_c*(7) =  + 0.0384997477137 * X_leu__L_e(6)
# X_dctp_c*(9) =
# X_thf_c*(19) =  + 0.0106030529898 * X_leu__L_e(6)
# X_25aics_c*(13) =  + 7.77082321776e-09 * X_leu__L_e(6)
# X_ni2_c*(0) =
# X_dtdp4d6dg_c*(16) =
# X_malcoa_c*(24) =  + 0.000782748812951 * X_leu__L_e(6)
# X_bm_cw_c*(1) =
# X_ACP_c*(0) =
# X_mlthf_c*(20) =  + 0.0028281834621 * X_leu__L_e(6)
# X_h_p*(0) =
# X_dhf_c*(19) =
# X_dudp_c*(9) =
# X_3omrsACP_c*(0) =
# X_trnaglu_c*(0) =
# X_pre6a_c*(44) =
# X_ametam_c*(14) =
# X_3hhexACP_c*(0) =
# X_4ppan_c*(9) =
# X_quln_c*(7) =
# X_frdp_c*(15) =
# X_glyald_c*(3) =
# X_uacgam_c*(17) =  + 0.102219825923 * X_leu__L_e(6)
# X_pram_c*(5) =  + 9.82868243107e-06 * X_leu__L_e(6)
# X_26dap__M_c*(7) =  + 0.00426284364716 * X_leu__L_e(6)
# X_gdpmann_c*(16) =  + 3.40571629407e-05 * X_leu__L_e(6)
# X_db4p_c*(4) =
# X_neuspn_c*(40) =
# X_actACP_c*(0) =
# X_actp_c*(2) =
# X_ugmd_c*(35) =  + 0.134037736854 * X_leu__L_e(6)
# X_s7p_c*(7) =  + 0.0447037733936 * X_leu__L_e(6)
# X_cbm_c*(1) =
# X_co2_c*(1) =  + 0.00544603925584 * X_leu__L_e(6)
# X_zeax_c*(40) =
# X_ptrc_c*(4) =
# X_adp_c*(10) =  + 5.92568969733 * X_leu__L_e(6)
# X_ncam_c*(6) =
# X_3a2oxpp_c*(3) =
# X_aspsa_c*(4) =
# X_tdec2eACP_c*(0) =
# X_phom_c*(4) =  + 9.64537997274e-06 * X_leu__L_e(6)
# X_5mdr1p_c*(6) =
# X_rb15bp_cx*(5) =  + 0.0451202242919 * X_leu__L_e(6)
# X_bcryptox_c*(40) =
# X_spmd_c*(7) =
# X_udpsq_c*(15) =
# X_adocbip_c*(58) =
# X_phycy_c*(33) =  + 4.1360270121 * X_leu__L_e(6)
# X_Ncbmpts_c*(5) =
# X_nadh_c*(21) =  + 2.90869893738 * X_leu__L_e(6)
# X_aps_c*(10) =  + 0.0105959008348 * X_leu__L_e(6)
# X_dpcoa_c*(21) =
# X_xu5p__D_c*(5) =
# X_no2_c*(0) =
# X_4hbz_c*(7) =
# X_3odecACP_c*(0) =
# X_dhnpt_c*(9) =
# X_5aprbu_c*(9) =
# X_iasp_c*(4) =
# X_nmn_c*(11) =  + 0.0257837187499 * X_leu__L_e(6)
# X_bm_pigm_c*(1) =
# X_2cpr5p_c*(12) =
# X_pchlld_c*(35) =
# X_o2_u*(0) =
# X_ala__L_c*(3) =  + 0.0141896902831 * X_leu__L_e(6)
# X_3c2hmp_c*(7) =
# X_pyr_c*(3) =  + 0.161270837589 * X_leu__L_e(6)
# X_hco3_c*(1) =  + 0.024107679285 * X_leu__L_e(6)
# X_pan4p_c*(11) =
# X_citac_c*(5) =  + 1.02683281208e-05 * X_leu__L_e(6)
# X_h2o_c*(0) =
# X_h_c*(0) =
# X_ugmda_c*(41) =  + 0.174997617744 * X_leu__L_e(6)
# X_pq_um*(53) =  + 6.186603329 * X_leu__L_e(6)
# X_man6p_c*(6) =
# X_cobalt2_c*(0) =
# X_gam1p_c*(6) =
# X_argsuc_c*(10) =  + 2.07584697503e-05 * X_leu__L_e(6)
# X_dhap_c*(3) =
# X_mn2_c*(0) =
# X_u3hga2_c*(31) =
# X_sprm_c*(10) =
# X_2h3oppan_c*(3) =
# X_2obut_c*(4) =  + 1.10664146278e-05 * X_leu__L_e(6)
# X_dtmp_c*(10) =
# X_fpram_c*(8) =  + 2.09355014233e-05 * X_leu__L_e(6)
# X_ump_c*(9) =  + 0.0692121204624 * X_leu__L_e(6)
# X_3pg_cx*(3) =  + 0.0528626881889 * X_leu__L_e(6)
# X_pq_cm*(53) =  + 0.0426035090388 * X_leu__L_e(6)
# X_ahdt_c*(9) =
# X_4mop_c*(6) =  + 7.23089056247e-07 * X_leu__L_e(6)
# X_npdp_c*(45) =
# X_dhor__S_c*(5) =  + 1.08954288212e-06 * X_leu__L_e(6)
# X_3opalmACP_c*(0) =
# X_glx_c*(2) =  + 0.0046749120806 * X_leu__L_e(6)
# X_thdp_c*(7) =  + 9.53242965985e-06 * X_leu__L_e(6)
# X_fprica_c*(10) =  + 1.77987937317e-05 * X_leu__L_e(6)
# X_adocbl_c*(72) =
# X_thr__L_c*(4) =  + 9.64537997274e-06 * X_leu__L_e(6)
# X_so3_c*(0) =
# X_2m6sbenzq_c*(52) =
# X_hco3_cx*(1) =  + 0.00791955832923 * X_leu__L_e(6)
# X_glu5p_c*(5) =  + 7.9960184423e-06 * X_leu__L_e(6)
# X_3hmrsACP_c*(0) =
# X_4c2me_c*(14) =  + 2.36146212306e-05 * X_leu__L_e(6)
# X_damp_c*(10) =
# X_histda_c*(6) =
# X_gthox_c*(20) =  + 0.0346730759527 * X_leu__L_e(6)
# X_amp_c*(10) =  + 0.441696082022 * X_leu__L_e(6)
# X_23dhmb_c*(5) =
# X_5mdru1p_c*(6) =
# X_mppp9_c*(34) =
# X_cdp_c*(9) =  + 2.44459346687e-05 * X_leu__L_e(6)
# X_dcaACP_c*(0) =
# X_2me4p_c*(5) =  + 5.62548127369e-06 * X_leu__L_e(6)
# X_3hpalmACP_c*(0) =
# X_2ahbut_c*(6) =  + 9.87661472292e-06 * X_leu__L_e(6)
# X_caro_c*(40) =
# X_3dhq_c*(7) =
# X_4adcho_c*(10) =
# X_glu__L_c*(5) =  + 0.14160524716 * X_leu__L_e(6)
# X_bm_cofactors_c*(1) =
# X_34hpp_c*(9) =  + 1.29889069242e-05 * X_leu__L_e(6)
# X_ctp_c*(9) =  + 0.068471213214 * X_leu__L_e(6)
# X_pqh2_cm*(53) =  + 0.0426035090389 * X_leu__L_e(6)
# X_fad_c*(27) =
# X_2shchc_c*(11) =
# X_dhna_c*(11) =
# X_co2_cx*(1) =  + 0.00791955832974 * X_leu__L_e(6)
# X_acg5sa_c*(7) =
# X_ala__D_c*(3) =  + 0.0315883091565 * X_leu__L_e(6)
# X_aicar_c*(9) =  + 5.37980068922e-09 * X_leu__L_e(6)
# X_g6p_c*(6) =  + 0.173049968264 * X_leu__L_e(6)
# X_glu5sa_c*(5) =  + 5.4501766903e-06 * X_leu__L_e(6)
# X_zcarote_c*(40) =
# X_pre3b_c*(43) =
# X_mthgxl_c*(3) =
# X_3mop_c*(6) =  + 1.41933424509e-05 * X_leu__L_e(6)
# X_5drib_c*(5) =
# X_e4hglu_c*(5) =
# X_dgtp_c*(10) =
# X_cys__L_c*(3) =  + 0.0307340433934 * X_leu__L_e(6)
# X_bm_rna_c*(1) =
# X_hisp_c*(6) =
# X_lycop_c*(40) =
# X_citr__L_c*(6) =  + 9.86018360154e-06 * X_leu__L_e(6)
# X_2ahhmp_c*(7) =
# X_pdx5p_c*(8) =
# X_fru_c*(6) =  + 0.0388064806141 * X_leu__L_e(6)
# X_2mecdp_c*(5) =  + 9.34203630024e-06 * X_leu__L_e(6)
# X_cbasp_c*(5) =
# X_dnad_c*(21) =  + 0.0311880429211 * X_leu__L_e(6)
# X_datp_c*(10) =
# X_prlp_c*(15) =
# X_toctd2eACP_c*(0) =
# X_cholphya_c*(55) =  + 13.7818783192 * X_leu__L_e(6)
# X_glc__D_c*(6) =  + 0.0388064806141 * X_leu__L_e(6)
# X_o2_cx*(0) =
# X_orot5p_c*(10) =
# X_k_c*(0) =
# X_amet_c*(15) =
# X_dtdprmn_c*(16) =
# X_2ippm_c*(7) =
# X_pro__L_c*(5) =  + 1.07596930782e-05 * X_leu__L_e(6)
# X_cpppg3_c*(36) =
# X_h2mb4p_c*(5) =  + 9.34203630024e-06 * X_leu__L_e(6)
# X_thmmp_c*(12) =
# X_cdpglc_c*(15) =
# X_xmp_c*(10) =
# X_co2dam_c*(45) =
# X_fdxox_c*(0) =
# X_orn_c*(5) =  + 9.74394355384e-06 * X_leu__L_e(6)
# X_2ahhmd_c*(7) =
# X_pre6b_c*(44) =
# X_gln__L_c*(5) =  + 0.0984223310351 * X_leu__L_e(6)
# X_3ohexACP_c*(0) =
# X_3pg_c*(3) =  + 0.0847565854611 * X_leu__L_e(6)
# X_pheme_c*(34) =
# X_methf_c*(20) =  + 0.0111736763688 * X_leu__L_e(6)
# X_co1dam_c*(45) =
# X_mppp9me_c*(35) =
# X_bm_dna_c*(1) =
# X_fe3_c*(0) =
# X_zn2_c*(0) =
# X_hexACP_c*(0) =
# X_prephytedp_c*(40) =
# X_glu1sa_c*(5) =
# X_chor_c*(10) =  + 4.67496630575e-05 * X_leu__L_e(6)
# X_4per_c*(4) =
# X_hemeA_c*(49) =
# X_glucys_c*(8) =  + 0.0878564259836 * X_leu__L_e(6)
# X_dmpp_c*(5) =
# X_inost_c*(6) =
# X_4hthdp_c*(7) =
# X_applp_c*(3) =
# X_oaa_c*(4) =
# X_no3_c*(0) =
# X_uamag_c*(28) =  + 0.0135770772257 * X_leu__L_e(6)
# X_dialurate_c*(4) =
# X_gcarote_c*(40) =
# X_ser__L_c*(3) =  + 0.018822705137 * X_leu__L_e(6)
# X_1pyr5c_c*(5) =  + 1.18216195763e-05 * X_leu__L_e(6)
# X_ppi_c*(0) =
# X_ribflv_c*(17) =
# X_tyr__L_c*(9) =
# X_pap_c*(10) =  + 2.4493953792e-05 * X_leu__L_e(6)
# X_oxa_c*(2) =  + 0.000453588906174 * X_leu__L_e(6)
# X_25dhpp_c*(9) =
# X_3nphb_c*(52) =
# X_h2o_p*(0) =
# X_pre8_c*(45) =
# X_3dhsk_c*(7) =
# X_dhpmp_c*(9) =
# X_glyc__R_c*(3) =  + 0.0191814168748 * X_leu__L_e(6)
# X_dad_5_c*(10) =
# X_2dda7p_c*(7) =
# X_acglu_c*(7) =  + 1.36576703698e-05 * X_leu__L_e(6)
# X_imp_c*(10) =
# X_nad_c*(21) =  + 0.15332161136 * X_leu__L_e(6)
# X_dcamp_c*(14) =  + 7.14542060649e-06 * X_leu__L_e(6)
# X_bm_carbs_c*(1) =
# X_2ahethmpp_c*(14) =  + 3.9510381412e-05 * X_leu__L_e(6)
# X_imacp_c*(6) =
# X_dmlz_c*(13) =
# X_g3p_c*(3) =  + 0.412568164097 * X_leu__L_e(6)
# X_dadp_c*(10) =
# X_o2_p*(0) =
# X_fmnh2_c*(17) =
# X_nadph_c*(21) =  + 0.188369397983 * X_leu__L_e(6)
# X_cbp_c*(1) =  + 6.47114380869e-06 * X_leu__L_e(6)
# X_mi3p__D_c*(6) =
# X_tmrs2eACP_c*(0) =
# X_6pgl_c*(6) =  + 0.0248203836058 * X_leu__L_e(6)
# X_ppp9_c*(34) =
# X_mobd_c*(0) =
# X_bm_memlip_c*(1) =
# X_dad_2_c*(10) =
# X_biliverd_c*(33) =
# X_pre4_c*(44) =
# X_ggdp_c*(20) =
# X_pre3a_c*(43) =
# X_rb15bp_c*(5) =  + 0.0451202242919 * X_leu__L_e(6)
# X_3hbutACP_c*(0) =
# X_histd_c*(6) =
# X_pphn_c*(10) =  + 3.81985859726e-05 * X_leu__L_e(6)
# X_nicrnt_c*(11) =  + 0.0129401896329 * X_leu__L_e(6)
# X_3ooctdACP_c*(0) =
# X_atp_c*(10) =  + 4.64165753385 * X_leu__L_e(6)
# X_lipidX2_c*(38) =
# X_2pg_c*(3) =
# X_pppg9_c*(34) =
# X_uagmda_c*(87) =  + 0.351593330605 * X_leu__L_e(6)
# X_met__L_c*(5) =
# X_phyto_c*(40) =
# X_4hpro_LT_c*(5) =
# X_1p3h5c_c*(5) =
# X_hemeO_c*(49) =
# X_lgt__S_c*(13) =
# X_h2o_u*(0) =
# X_adcobhex_c*(55) =
# X_co_c*(1) =
# X_sbzcoa_c*(32) =
# X_e4p_c*(4) =
# X_accoa_c*(23) =  + 0.119973806049 * X_leu__L_e(6)
# X_asn__L_c*(4) =  + 0.0200216659988 * X_leu__L_e(6)
# X_mal__L_c*(4) =
# X_ocdcaACP_c*(0) =
# X_ichor_c*(10) =
# X_pant__R_c*(6) =
# X_phdp_c*(20) =
# X_r5p_c*(5) =
# X_grdp_c*(10) =
# X_ohpb_c*(4) =
# X_ipdp_c*(5) =
# X_arg__L_c*(6) =  + 1.24550818502e-05 * X_leu__L_e(6)
# X_phe__L_c*(9) =
# X_acgam1p_c*(8) =  + 0.0173734452218 * X_leu__L_e(6)
# X_nadp_c*(21) =  + 3.12471721159 * X_leu__L_e(6)
# X_3ig3p_c*(11) =
# X_val__L_c*(5) =
# X_dmbzid_c*(9) =
# X_2a3pp_c*(4) =
# X_3mob_c*(5) =
# X_5prdmbz_c*(14) =
# X_rdmbzi_c*(14) =
# X_5mthf_c*(20) =
# X_3hoctACP_c*(0) =
# X_dvpchlda_c*(35) =
# X_10fthf_c*(20) =  + 0.0111736763688 * X_leu__L_e(6)
# X_4r5au_c*(9) =
# X_skm_c*(7) =  + 1.70734160067e-05 * X_leu__L_e(6)
# X_gar_c*(7) =  + 1.74370726911e-05 * X_leu__L_e(6)
# X_dmtphllqne_c*(30) =
# X_skm5p_c*(7) =  + 3.23743855598e-05 * X_leu__L_e(6)
# X_citm_c*(5) =  + 1.02683281208e-05 * X_leu__L_e(6)
# X_udpg_c*(15) =  + 0.0731581720595 * X_leu__L_e(6)
# X_5mta_c*(11) =
# X_dcdp_c*(9) =
# X_pcrd_u*(0) =
# X_myrsACP_c*(0) =
# X_glutrna_c*(0) =
# X_adcobdam_c*(55) =
# X_nh4_c*(0) =
# X_hom__L_c*(4) =
# X_acser_c*(5) =
# X_pre5_c*(45) =
# X_fdxrd_c*(0) =
# X_sucbz_c*(11) =
# X_prpp_c*(5) =  + 1.5892728286e-05 * X_leu__L_e(6)
# X_5aizc_c*(9) =
# X_dtdp4d6dm_c*(16) =
# X_but2eACP_c*(0) =
# X_chlld_c*(35) =
# X_h_u*(0) =
# X_gly_c*(2) =  + 0.159710271426 * X_leu__L_e(6)
# X_uppg3_c*(40) =
# X_dtdp_c*(10) =
# X_uamr_c*(20) =  + 0.0619147100232 * X_leu__L_e(6)
# X_trp__L_c*(11) =
# X_udcpdp_c*(55) =  + 0.212967436717 * X_leu__L_e(6)
# X_lipidAds2_c*(76) =
# X_hpyr_c*(3) =  + 0.0123566380678 * X_leu__L_e(6)
# X_hcys__L_c*(4) =
# X_prbatp_c*(15) =
# X_indole_c*(8) =
# X_dscl_c*(42) =
# X_glycogen_c*(0) =
# X_5aop_c*(5) =
# X_gthrd_c*(10) =  + 0.137119887264 * X_leu__L_e(6)
# X_fgam_c*(8) =  + 1.61142034712e-05 * X_leu__L_e(6)
# X_adpglc_c*(16) =  + 0.612011938189 * X_leu__L_e(6)
# X_air_c*(8) =  + 2.26678595014e-05 * X_leu__L_e(6)
# X_3hoctaACP_c*(0) =
# X_hmbil_c*(40) =
# X_3psme_c*(10) =  + 4.67496630575e-05 * X_leu__L_e(6)
# X_thrp_c*(4) =
# X_dtdpglu_c*(16) =
# X_thmpp_c*(12) =  + 3.66615778889e-05 * X_leu__L_e(6)
# X_tpalm2eACP_c*(0) =
# X_h2o2_c*(0) =
# X_alaala_c*(6) =  + 0.0351755740085 * X_leu__L_e(6)
# X_pran_c*(12) =
# X_tddec2eACP_c*(0) =
# X_icit_c*(6) =  + 5.05550861581e-05 * X_leu__L_e(6)
# X_3ooctACP_c*(0) =
# X_4ampm_c*(6) =
# X_adn_c*(10) =  + 0.0149185675672 * X_leu__L_e(6)
# X_4pasp_c*(4) =  + 2.26736278313e-05 * X_leu__L_e(6)
# X_3php_c*(3) =
# X_ppbng_c*(10) =
# X_acorn_c*(7) =  + 8.73239049892e-07 * X_leu__L_e(6)
# X_ile__L_c*(6) =
# X_3c3hmp_c*(7) =  + 5.355600627e-07 * X_leu__L_e(6)
# X_phthr_c*(4) =
# X_cynt_c*(1) =
# X_pqh2_c*(53) =
# X_cthzp_c*(7) =
# X_dna5mtc_c*(0) =
# X_dna_c*(0) =
# X_14glucan_c*(0) =
# X_cobalt2_p*(0) =
# X_zn2_p*(0) =
# X_so4_p*(0) =
# X_spmd_p*(7) =
# X_ca2_p*(0) =
# X_nh4_p*(0) =
# X_arg__L_p*(6) =
# X_gln__L_p*(5) =
# X_mn2_p*(0) =
# X_hco3_p*(1) =
# X_mg2_p*(0) =
# X_ptrc_p*(4) =
# X_fe2_p*(0) =
# X_cu2_p*(0) =
# X_k_p*(0) =
# X_no3_p*(0) =
# X_fe3_p*(0) =
# X_mobd_p*(0) =
# X_ni2_p*(0) =
# X_cynt_p*(1) =
# X_pi_p*(0) =
# X_h2o_e*(0) =
# X_co2_e*(1) =
# X_his__L_e*(6) =
# X_cobalt2_e*(0) =
# X_zn2_e*(0) =
# X_spmd_e*(7) =
# X_ca2_e*(0) =
# X_nh4_e*(0) =
# X_arg__L_e*(6) =
# X_gln__L_e*(5) =
# X_mn2_e*(0) =
# X_hco3_e*(1) =
# X_mg2_e*(0) =
# X_ptrc_e*(4) =
# X_fe2_e*(0) =
# X_cu2_e*(0) =
# X_k_e*(0) =
# X_fe3_e*(0) =
# X_mobd_e*(0) =
# X_ni2_e*(0) =
# X_na1_e*(0) =
# X_cynt_e*(1) =
# X_co2_p*(1) =
# X_h_e*(0) =
# X_na1_p*(0) =
# X_dkmpp_c*(6) =
# X_dhmtp_c*(6) =
# X_2kmb_c*(5) =
# X_tczcaro_c*(40) =
# X_dczcaro_c*(40) =
# X_ttclyco_c*(40) =
# X_phptna_c*(55) =
# X_phphbda_c*(35) =
# X_phytol_c*(20) =
# X_rcc_c*(35) =
# X_6pthp_c*(9) =
# X_thbpt_c*(9) =
# X_gthbpt_c*(15) =
# X_iscssh_c*(0) =
# X_iscsh_c*(0) =
# X_this_c*(0) =
# X_athis_c*(0) =
# X_thissh_c*(0) =
# X_imgly_c*(2) =  + 0.00480446671552 * X_leu__L_e(6)
# X_2c4mthzep_c*(7) =
# X_sheme_c*(42) =
# X_malcoame_c*(25) =
# X_ogmeACP_c*(0) =
# X_hgmeACP_c*(0) =
# X_egmeACP_c*(0) =
# X_gmeACP_c*(0) =
# X_opmeACP_c*(0) =
# X_hpmeACP_c*(0) =
# X_epmeACP_c*(0) =
# X_pmeACP_c*(0) =
# X_pimACP_c*(0) =
# X_meoh_c*(1) =
# X_8aonn_c*(9) =
# X_dann_c*(9) =
# X_amob_c*(15) =
# X_dtbt_c*(10) =
# X_btn_c*(10) =
# X_btamp_c*(20) =
# X_accp_c*(0) =
# X_btnCCP_c*(0) =
# X_octapb_c*(8) =
# X_lipopb_c*(8) =
# X_lipoate_c*(8) =
# X_lipamp_c*(18) =
# X_meoh_p*(1) =
# X_meoh_e*(1) =
# X_cph4_c*(7) =
# X_cdg_c*(7) =
# X_preq0_c*(7) =
# X_preq1_c*(7) =
# X_preqtrna_c*(7) =
# X_epxqtrna_c*(12) =
# X_quetrna_c*(12) =
# X_ura_c*(4) =
# X_udpglcur_c*(15) =
# X_udpxyl_c*(14) =
# X_gdpddman_c*(16) =
# X_gdpfuc_c*(16) =
# X_glyc_c*(3) =
# X_cdp4dh6doglc_c*(15) =
# X_sucr_c*(12) =  + 0.0776129612281 * X_leu__L_e(6)
# X_ocdca_c*(18) =
# X_ocdcal_c*(18) =
# X_hpdcn_c*(17) =
# X_1hdecg3p_c*(19) =
# X_1hdec9eg3p_c*(19) =
# X_1odec9eg3p_c*(21) =
# X_pa160_c*(35) =  + 0.0232707876469 * X_leu__L_e(6)
# X_pa1619Z160_c*(35) =  + 0.0233023939472 * X_leu__L_e(6)
# X_pa161_c*(35) =  + 0.0233023955137 * X_leu__L_e(6)
# X_pa1819Z1619Z_c*(37) =  + 0.108401534222 * X_leu__L_e(6)
# X_pa1819Z160_c*(37) =  + 0.0674643226229 * X_leu__L_e(6)
# X_12dgr160_c*(35) =  + 0.023277099566 * X_leu__L_e(6)
# X_12dgr1619Z160_c*(35) =  + 0.0233355610429 * X_leu__L_e(6)
# X_12dgr161_c*(35) =  + 0.0233233690479 * X_leu__L_e(6)
# X_12dgr1819Z1619Z_c*(37) =  + 0.108413101339 * X_leu__L_e(6)
# X_12dgr1819Z160_c*(37) =  + 0.0674843118174 * X_leu__L_e(6)
# X_sqdg160_c*(41) =
# X_sqdg1619Z160_c*(41) =
# X_mgdg1619Z160_c*(41) =
# X_dgdg1619Z160_c*(47) =
# X_dgdg161_c*(47) =
# X_mgdg161_c*(41) =
# X_dgdg1819Z1619Z_c*(49) =
# X_mgdg1819Z1619Z_c*(43) =
# X_cdp12dgr1819Z160_c*(46) =
# X_pgp1819Z160_c*(40) =
# X_pg1819Z160_c*(40) =
# X_glcdg1619Z160_c*(41) =
# X_glcdg161_c*(41) =
# X_glcdg1819Z1619Z_c*(43) =
# X_glcdg1819Z160_c*(43) =
# X_mgdg1819Z160_c*(43) =
# X_dgdg1819Z160Z_c*(49) =
# X_glntrna_c*(0) =
# X_trnagln_c*(0) =
# X_trnatyr_c*(0) =
# X_tyrtrna_c*(0) =
# X_trnamet_c*(0) =
# X_mettrna_c*(0) =
# X_trnaser_c*(0) =
# X_sertrna_c*(0) =
# X_glytrna_c*(0) =
# X_trnagly_c*(0) =
# X_protrna_c*(0) =
# X_trnapro_c*(0) =
# X_trnacys_c*(0) =
# X_cystrna_c*(0) =
# X_trnaarg_c*(0) =
# X_argtrna_c*(0) =
# X_trnatrp_c*(0) =
# X_trptrna_c*(0) =
# X_phetrna_c*(0) =
# X_trnaphe_c*(0) =
# X_trnahis_c*(0) =
# X_histrna_c*(0) =
# X_trnaasn_c*(0) =
# X_asntrna_c*(0) =
# X_asptrna_c*(0) =
# X_trnaasp_c*(0) =
# X_trnathr_c*(0) =
# X_thrtrna_c*(0) =
# X_trnaleu_c*(0) =
# X_leutrna_c*(0) =
# X_trnaile_c*(0) =
# X_iletrna_c*(0) =
# X_trnalys_c*(0) =
# X_lystrna_c*(0) =
# X_alatrna_c*(0) =
# X_trnaala_c*(0) =
# X_valtrna_c*(0) =
# X_trnaval_c*(0) =
# X_fmettrna_c*(0) =
# X_calxan_c*(40) =
# X_nstxan_c*(40) =
# X_chla_soret_exc_c*(55) =  + 0.0712257398258 * X_leu__L_e(6)
# X_bcaro_exc_c*(0) =
# X_phycy_exc_c*(0) =
# X_allocy_exc_c*(0) =
# X_allocy_c*(33) =  + 4.1360270121 * X_leu__L_e(6)
# X_chla_qy1_exc_c*(55) =  + 6.1270157024 * X_leu__L_e(6)
# X_pho_loss_c*(0) =
# X_u23ga2_c*(47) =
# X_u3aga2_c*(33) =
# X_ara5p_c*(5) =
# X_kdo8p_c*(8) =
# X_kdo_c*(8) =
# X_ckdo_c*(17) =
# X_uacmam_c*(17) =
# X_udcpp_c*(55) =  + 0.21296936713 * X_leu__L_e(6)
# X_unaga_c*(63) =
# X_kdolipid4cy_c*(84) =
# X_unagam_c*(71) =
# X_icolipacy_c*(1) =
# X_icolipacy_p*(1) =
# X_oanticy_c*(1) =
# X_oanticy_p*(1) =
# X_colipacy_p*(1) =
# X_colipacy_e*(1) =
# X_uaagmda_c*(95) =  + 0.367852845238 * X_leu__L_e(6)
# X_murein5p5p_p*(80) =  + 0.150278613323 * X_leu__L_e(6)
# X_murein5p5p5p_p*(120) =  + 0.0138203855953 * X_leu__L_e(6)
# X_ala__D_p*(3) =  + 0.0116148380419 * X_leu__L_e(6)
# X_murein5px4px4p_p*(114) =  + 0.0131095100849 * X_leu__L_e(6)
# X_murein5px4p_p*(77) =  + 0.125083639068 * X_leu__L_e(6)
# X_alaala_p*(6) =
# X_murein5px3p_p*(74) =
# X_murein4px4p_p*(74) =  + 0.0250677719147 * X_leu__L_e(6)
# X_murein4px4px4p_p*(111) =  + 0.0127645229774 * X_leu__L_e(6)
# X_murein5p4p_p*(77) =  + 0.11854572072 * X_leu__L_e(6)
# X_murein4p4p_p*(74) =  + 0.138994828192 * X_leu__L_e(6)
# X_murein4p3p_p*(71) =
# X_murein5p3p_p*(74) =
# X_murein3px4p_p*(71) =
# X_murein4px4p4p_p*(111) =  + 0.0127645229774 * X_leu__L_e(6)
# X_murein3p3p_p*(68) =
# X_anhgm4p_p*(37) =  + 0.00425484099247 * X_leu__L_e(6)
# X_anhgm3p_p*(34) =
# X_anhgm_c*(19) =  + 0.00107063526805 * X_leu__L_e(6)
# X_LalaDgluMdapDala_c*(18) =  + 0.068136582588 * X_leu__L_e(6)
# X_anhgm4p_c*(37) =  + 0.142791403339 * X_leu__L_e(6)
# X_anhgm_p*(19) =  + 0.000235325704009 * X_leu__L_e(6)
# X_LalaDgluMdapDala_p*(18) =  + 0.000222940140641 * X_leu__L_e(6)
# X_anhgm3p_c*(34) =  + 0.00149476449609 * X_leu__L_e(6)
# X_acgam_c*(8) =  + 0.0309729014452 * X_leu__L_e(6)
# X_anhm4p_c*(29) =  + 0.109367694025 * X_leu__L_e(6)
# X_LalaDgluMdap_p*(15) =
# X_anhm_c*(11) =  + 0.0425877394871 * X_leu__L_e(6)
# X_anhm3p_c*(26) =  + 0.00228611040579 * X_leu__L_e(6)
# X_LalaDgluMdap_c*(15) =  + 0.0534646096427 * X_leu__L_e(6)
# X_LalaDglu_c*(8) =  + 0.00488813924073 * X_leu__L_e(6)
# X_um4p_c*(38) =  + 0.011686499958 * X_leu__L_e(6)
# X_LalaLglu_c*(8) =  + 0.00488813924069 * X_leu__L_e(6)
# X_pchlld_exc_c*(35) =
# X_fldox_c*(17) =
# X_fldrd_c*(17) =
# X_5g2oxpt_p*(6) =
# X_h2o2_p*(0) =
# X_leu__L_p*(6) =  + 1.00000000003 * X_leu__L_e(6)
# X_no2_p*(0) =
# X_no2_e*(0) =
# X_zeax_exc_c*(0) =
# X_chla_qy2_exc_c*(55) =  + 7.16987191519 * X_leu__L_e(6)
# X_p700_um*(55) =  + 6.86308512495 * X_leu__L_e(6)
# X_p700_exc_um*(55) =  + 6.86308512495 * X_leu__L_e(6)
# X_p680_exc_um*(55) =  + 6.838407998 * X_leu__L_e(6)
# X_p680_um*(55) =  + 6.84782873479 * X_leu__L_e(6)
# X_b14glucan_c*(12) =
# X_fald_c*(1) =
# X_hmgth_c*(11) =
# X_Sfglutth_c*(11) =
# X_5oxpro_c*(5) =  + 0.000953837239138 * X_leu__L_e(6)
# X_acgam6p_c*(8) =  + 0.0740851307952 * X_leu__L_e(6)
# X_acmanap_c*(8) =
# X_acmum6p_c*(11) =  + 0.0502915437344 * X_leu__L_e(6)
# X_cl_p*(0) =
# X_cl_c*(0) =
# X_cl_e*(0) =
# X_k_u*(0) =
# X_ps2d1_um*(0) =
# X_ps2d1_exc_um*(0) =
# X_lac__D_c*(3) =  + 0.0137158755639 * X_leu__L_e(6)
# X_fum_c*(4) =  + 1.03473276673e-05 * X_leu__L_e(6)
# X_h2_c*(0) =
# X_succ_c*(4) =
# X_ac_c*(2) =  + 0.0181757511813 * X_leu__L_e(6)
# X_for_c*(1) =  + 0.000781232067088 * X_leu__L_e(6)
# X_akg_c*(5) =
# X_o2_e*(0) =
#        finishing in 12.462478160858154  s
# Global execution time =  18.159852027893066  s

# %%
# misc. Une tentative d'écriture de convertisseur Modèle Cobra vers modèle nutrition analyzer (.mdl)
# Attention, nutrition analyzer ne traite que des réactions irréversibles et dont le flux est positif. 
# Le convertisseur gère les réactions qui ne sont pas écrites dans le modèle cobra dans le bon sens mais
# il faut que les lower et upper bounds soient de même signe.

def toMDL(model,atom="C"):
    # reactions
    i=1
    ch=""
    for r in model.reactions:
        ch+=str(i)+";"+r.id
        for m in model.metabolites:
            if m in r.metabolites:
                if (r.lower_bound>=0):
                    ch+=";"+str(r.get_coefficient(m))
                else:
                    ch+=";"+str(-r.get_coefficient(m))
            else:
                ch+=";0"
        ch+=";0\n"
        i+=1
    # repartition carbones
    ch+=str(i)+";Carbones"
    for m in model.metabolites:
        ch+=";"+str(GetComposition(m.formula,atom))
    ch+=";1\n"
    i+=1
    
    ch="BEGIN Matrice\n"+ch+"END\n"
    
    # Nom colonnes
    
    chcolname="ID\nR_Name\n"
    for m in model.metabolites:
        chcolname+=m.name+"\n"
    chcolname+="Repart. Carbones\n"
    chcolname="BEGIN NomsColonnes\n"+chcolname+"END\n"

    
    # Type colonnes
    chcoltype="2\n1\n"
    for m in model.metabolites:
        chcoltype+="3\n"
    chcoltype+="9\n"
    chcoltype="BEGIN TypesColonnes\n"+chcoltype+"END\n"
    
    # reactions utilisées
    chReactut="0\n"
    for r in model.reactions:
        chReactut+="on\n"
    chReactut+="0\n"
    chReactut="BEGIN EquationsUtilisees\n"+chReactut+"END\n"


    # Contraintes et objectif
    chReactres=""
    objectif="Maximize "
    i=1;
    for r in model.reactions:
        if (r.lower_bound>=0):
            chReactres+="R_"+str(i)+">"+str(r.lower_bound)+"\n"
            chReactres+="R_"+str(i)+"<"+str(r.upper_bound)+"\n"
        else:
            chReactres+="R_"+str(i)+">"+str(-r.upper_bound)+"\n"
            chReactres+="R_"+str(i)+"<"+str(-r.lower_bound)+"\n"            
        if (not r.objective_coefficient == 0):
            if (r.lower_bound>=0):
                sign=1
            else:
                sign=-1
            if r.objective_coefficient*sign == 1:
                objectif+= "+"+str(sign)+"* R_"+str(i);
            else:
                objectif+= " + "+str(sign*r.objective_coefficient)+" * R_"+str(i);
        i+=1

                
    chReactres="BEGIN contraintes\n"+chReactres+objectif+"\nEND\n"
    
    
    return ch+chReactut+chcolname+chcoltype+chReactres

# %%
# exemple d'utilisation du convertisseur avec e coli core model

model= cobra.io.read_sbml_model("NA_Offline/e_coli_core.xml")

# on calcule un vecteur "optimal" pour avoir le sens des réactions
fba = model.optimize()
# on modifie les lower/upper bounds en conséquence
for r in model.reactions:
    if (fba.x_dict.get(r.id)>0):
        r.lower_bound=0
    else: 
        r.upper_bound=0

# export du modèle qui peut être utilisé dans nutrition analyzer
fd=open("SortieExpl.mdl","w")
fd.write(toMDL(model))
fd.close()
